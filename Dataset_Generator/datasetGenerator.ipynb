# %%
import json
import os
import re
import csv
import numpy as np
from annotationToString import convert_annotations_to_strings

annotations_folder = 'annotations'
final_annotations_file = 'final_annotations.json'

file_path = os.path.join(annotations_folder, final_annotations_file)

with open(file_path, 'r', encoding='utf-8') as f:
    final_data = json.load(f)
f.close()

# %%
def dataset_generator(final_data):

    dataset_aux = []
    final_rotulation = []
    item_count = 0
    patent_count = 0

    for index in range(len(final_data["annotations"])):
        annotation = final_data["annotations"][index]

        if annotation is not None and annotation[1]['entities']:
            
            patent_count += 1
            text = annotation[0]
            entities = annotation[1]
            
            match_length = len(re.match(r'\d_\d+_', text).group())
            text = re.sub(r'\d_\d+_', '', text)
            text = re.sub(r'\r', '', text)
            
            rotulation = convert_annotations_to_strings(text, entities, match_length)
            final_rotulation.append(rotulation)

            word_list = re.findall(r'\w+\s?|[^\w]\s?', text, re.UNICODE)
            start = 0
            end = 0
            sentence = 1

            for word in word_list:
                final_word = word.split()[0]
                end = start + len(word)-1
                dataset_aux.append([
                    item_count,
                    final_word,
                    'O',
                    start,
                    end,
                    sentence,
                    patent_count,
                ])
                item_count += 1
                start = start + len(word)
                if(word == '. '):
                    sentence += 1
    index = 0
    patent_num_aux = 1
    for word in dataset_aux:
        patent_num = word[6]
        if(patent_num != patent_num_aux):
            index += 1
        for entity in final_rotulation[index]:
            if(word[1] != '.'):
                if (word[3] == entity[2][0] and word[4] <= entity[2][1]):
                    word[2] = 'B-' + entity[1]
                elif (word[3] >= entity[2][0] and word[4] <= entity[2][1]):
                    word[2] = 'I-' + entity[1]
                    break
        patent_num_aux = patent_num

    dataset = [sublist[:3] + sublist[5:] for sublist in dataset_aux]
    return dataset

# %%
from numpy import floor


def partition_maker(dataset, partition_number):
    
    counters_patent = []
    count_aux = [0, 0, 0, 0, 0, 0]
    current_patent = dataset[0][4]
    
    category_map = {
        'FUNCIONALIDADE': 0,
        'HARDWARE': 1,
        'SOFTWARE': 2,
        'COMUNICAÇÃO': 3,
        'PESSOA': 4
    }

    for data in dataset:
        if data[4] != current_patent:
            count_aux[5] = current_patent
            counters_patent.append(count_aux)
            count_aux = [0, 0, 0, 0, 0, 0]
            current_patent = data[4]
        
        category = data[2].split('-')[-1]
        if category in category_map:
            count_aux[category_map[category]] += 1
    
    count_aux[5] = current_patent
    counters_patent.append(count_aux)
    
    counters_array = np.array(counters_patent)
    total_counts = np.sum(counters_array[:, :-1], axis=0)
    media = total_counts / partition_number
    
    sub_sets = [[np.zeros(5), []] for _ in range(partition_number)]

    print(media)
    
    for index in range(len(category_map) - 1, -1, -1):
        for partition in range(partition_number):
            while sub_sets[partition][0][index] < floor(media[index]):
                found = False
                for i, counter in enumerate(counters_array):
                    # Verificar se adicionar este counter vai desbalancear as outras categorias
                    would_balance = True
                    for j in range(len(category_map)):
                        if sub_sets[partition][0][j] + counter[j] > floor(media[j]):
                            would_balance = False
                            break
                    
                    if counter[index] > 0 and would_balance:
                        sub_sets[partition][0][:5] += counter[:-1]
                        sub_sets[partition][1].append(counter[5])
                        counters_array = np.delete(counters_array, i, 0)
                        found = True
                        break
                
                if not found:
                    break
    
    sub_sets[9][0][:5] += counters_array[2][:-1]
    sub_sets[9][1].append(counters_array[2][5])
    
    sub_sets[9][0][:5] += counters_array[0][:-1]
    sub_sets[9][1].append(counters_array[0][5])
    
    sub_sets[6][0][:5] += counters_array[4][:-1]
    sub_sets[6][1].append(counters_array[4][5])

    sub_sets[7][0][:5] += counters_array[3][:-1]
    sub_sets[7][1].append(counters_array[3][5])

    sub_sets[8][0][:5] += counters_array[1][:-1]
    sub_sets[8][1].append(counters_array[1][5])

    sub_sets[8][0][:5] += counters_array[5][:-1]
    sub_sets[8][1].append(counters_array[5][5])


    return [sub_set[1] for sub_set in sub_sets]

# %%
def reorder_patents(sub_sets, dataset):
    new_dataset = []
    count_item = 0
    count_patent = 1
    for index, sub_set in enumerate(sub_sets):
        for patent in sub_set:
            for data in dataset:
                if data[4] == patent:
                    
                    data_aux = data.copy()
                    
                    data_aux[0] = count_item
                    data_aux[4] = count_patent

                    partition = index + 1
                    data_aux.append(partition)

                    if(partition == 8):
                        data_aux.append("validation")
                    elif(partition > 8):
                        data_aux.append("test")
                    else:
                        data_aux.append("training")
                        
                    new_dataset.append(data_aux)
                    
                    count_item += 1

            count_patent += 1

    return new_dataset

# %%
dataset = dataset_generator(final_data)
sub_sets = partition_maker(dataset, 10)
dataset = reorder_patents(sub_sets, dataset)

for data in dataset:
    print(data)
# Out:
# [169.3  92.5  31.3  18.4   6.3]
# [0, 'Fitting', 'O', 1, 1, 1, 'training']
# [1, 'room', 'O', 1, 1, 1, 'training']
# [2, 'management', 'O', 1, 1, 1, 'training']
# [3, 'and', 'O', 1, 1, 1, 'training']
# [4, 'occupancy', 'B-SOFTWARE', 1, 1, 1, 'training']
# [5, 'monitoring', 'I-SOFTWARE', 1, 1, 1, 'training']
# [6, 'system', 'I-SOFTWARE', 1, 1, 1, 'training']
# [7, 'for', 'O', 1, 1, 1, 'training']
# [8, 'retail', 'O', 1, 1, 1, 'training']
# [9, 'operations', 'O', 1, 1, 1, 'training']
# [10, 'having', 'O', 1, 1, 1, 'training']
# [11, 'fitting', 'O', 1, 1, 1, 'training']
# [12, 'rooms', 'O', 1, 1, 1, 'training']
# [13, 'wherein', 'O', 1, 1, 1, 'training']
# [14, 'the', 'O', 1, 1, 1, 'training']
# [15, 'system', 'O', 1, 1, 1, 'training']
# [16, 'if', 'O', 1, 1, 1, 'training']
# [17, 'capable', 'O', 1, 1, 1, 'training']
# [18, 'of', 'O', 1, 1, 1, 'training']
# [19, 'notifying', 'B-FUNCIONALIDADE', 1, 1, 1, 'training']
# [20, 'staff', 'I-FUNCIONALIDADE', 1, 1, 1, 'training']
# [21, 'of', 'O', 1, 1, 1, 'training']
# [22, 'fitting', 'O', 1, 1, 1, 'training']
# [23, 'room', 'O', 1, 1, 1, 'training']
# [24, 'occupancy', 'O', 1, 1, 1, 'training']
# [25, ',', 'O', 1, 1, 1, 'training']
# [26, 'the', 'O', 1, 1, 1, 'training']
# [27, 'need', 'O', 1, 1, 1, 'training']
# [28, 'for', 'O', 1, 1, 1, 'training']
# [29, 'cleaning', 'O', 1, 1, 1, 'training']
# [30, ',', 'O', 1, 1, 1, 'training']
# [31, 'and', 'O', 1, 1, 1, 'training']
# [32, '/', 'O', 1, 1, 1, 'training']
# [33, 'or', 'O', 1, 1, 1, 'training']
# [34, 'the', 'O', 1, 1, 1, 'training']
# [35, 'need', 'O', 1, 1, 1, 'training']
# [36, 'for', 'O', 1, 1, 1, 'training']
# [37, 'customer', 'B-PESSOA', 1, 1, 1, 'training']
# [38, 'help', 'O', 1, 1, 1, 'training']
# [39, 'in', 'O', 1, 1, 1, 'training']
# [40, 'real', 'O', 1, 1, 1, 'training']
# [41, 'time', 'O', 1, 1, 1, 'training']
# [42, 'as', 'O', 1, 1, 1, 'training']
# [43, 'well', 'O', 1, 1, 1, 'training']
# [44, 'as', 'O', 1, 1, 1, 'training']
# [45, 'collecting', 'O', 1, 1, 1, 'training']
# [46, 'and', 'O', 1, 1, 1, 'training']
# [47, 'tracking', 'B-FUNCIONALIDADE', 1, 1, 1, 'training']
# [48, 'data', 'I-FUNCIONALIDADE', 1, 1, 1, 'training']
# [49, 'of', 'O', 1, 1, 1, 'training']
# [50, 'fitting', 'O', 1, 1, 1, 'training']
# [51, 'room', 'O', 1, 1, 1, 'training']
# [52, 'activity', 'O', 1, 1, 1, 'training']
# [53, 'according', 'O', 1, 1, 1, 'training']
# [54, 'to', 'O', 1, 1, 1, 'training']
# [55, 'preset', 'O', 1, 1, 1, 'training']
# [56, 'business', 'O', 1, 1, 1, 'training']
# [57, 'rules', 'O', 1, 1, 1, 'training']
# [58, '.', 'O', 1, 1, 1, 'training']
# [59, 'The', 'O', 2, 1, 1, 'training']
# [60, 'system', 'O', 2, 1, 1, 'training']
# [61, 'further', 'O', 2, 1, 1, 'training']
# [62, 'assists', 'B-FUNCIONALIDADE', 2, 1, 1, 'training']
# [63, 'retail', 'I-FUNCIONALIDADE', 2, 1, 1, 'training']
# [64, 'operations', 'I-FUNCIONALIDADE', 2, 1, 1, 'training']
# [65, 'with', 'O', 2, 1, 1, 'training']
# [66, 'reduction', 'O', 2, 1, 1, 'training']
# [67, 'of', 'O', 2, 1, 1, 'training']
# [68, 'theft', 'O', 2, 1, 1, 'training']
# [69, 'incidents', 'O', 2, 1, 1, 'training']
# [70, ',', 'O', 2, 1, 1, 'training']
# [71, 'improvement', 'O', 2, 1, 1, 'training']
# [72, 'of', 'O', 2, 1, 1, 'training']
# [73, 'conversion', 'O', 2, 1, 1, 'training']
# [74, 'rates', 'O', 2, 1, 1, 'training']
# [75, 'and', 'O', 2, 1, 1, 'training']
# [76, 'employee', 'O', 2, 1, 1, 'training']
# [77, 'compliance', 'O', 2, 1, 1, 'training']
# [78, 'rates', 'O', 2, 1, 1, 'training']
# [79, '.', 'O', 2, 1, 1, 'training']
# [80, 'A', 'O', 1, 2, 1, 'training']
# [81, 'display', 'B-HARDWARE', 1, 2, 1, 'training']
# [82, 'device', 'I-HARDWARE', 1, 2, 1, 'training']
# [83, 'is', 'O', 1, 2, 1, 'training']
# [84, 'provided', 'O', 1, 2, 1, 'training']
# [85, '.', 'O', 1, 2, 1, 'training']
# [86, 'The', 'O', 2, 2, 1, 'training']
# [87, 'display', 'B-HARDWARE', 2, 2, 1, 'training']
# [88, 'device', 'I-HARDWARE', 2, 2, 1, 'training']
# [89, 'includes', 'O', 2, 2, 1, 'training']
# [90, 'a', 'O', 2, 2, 1, 'training']
# [91, 'plurality', 'O', 2, 2, 1, 'training']
# [92, 'of', 'O', 2, 2, 1, 'training']
# [93, 'diffractive', 'O', 2, 2, 1, 'training']
# [94, 'optical', 'O', 2, 2, 1, 'training']
# [95, 'elements', 'O', 2, 2, 1, 'training']
# [96, 'each', 'O', 2, 2, 1, 'training']
# [97, 'configured', 'O', 2, 2, 1, 'training']
# [98, 'to', 'O', 2, 2, 1, 'training']
# [99, 'emit', 'B-FUNCIONALIDADE', 2, 2, 1, 'training']
# [100, 'light', 'I-FUNCIONALIDADE', 2, 2, 1, 'training']
# [101, 'guided', 'I-FUNCIONALIDADE', 2, 2, 1, 'training']
# [102, 'in', 'O', 2, 2, 1, 'training']
# [103, 'a', 'O', 2, 2, 1, 'training']
# [104, 'light', 'O', 2, 2, 1, 'training']
# [105, 'guide', 'O', 2, 2, 1, 'training']
# [106, 'plate', 'O', 2, 2, 1, 'training']
# [107, 'to', 'O', 2, 2, 1, 'training']
# [108, 'a', 'O', 2, 2, 1, 'training']
# [109, 'user', 'B-PESSOA', 2, 2, 1, 'training']
# [110, '.', 'O', 2, 2, 1, 'training']
# [111, 'Virtual', 'O', 3, 2, 1, 'training']
# [112, 'images', 'O', 3, 2, 1, 'training']
# [113, 'by', 'O', 3, 2, 1, 'training']
# [114, 'the', 'O', 3, 2, 1, 'training']
# [115, 'light', 'O', 3, 2, 1, 'training']
# [116, 'are', 'O', 3, 2, 1, 'training']
# [117, 'observed', 'O', 3, 2, 1, 'training']
# [118, 'by', 'O', 3, 2, 1, 'training']
# [119, 'the', 'O', 3, 2, 1, 'training']
# [120, 'user', 'B-PESSOA', 3, 2, 1, 'training']
# [121, 'at', 'O', 3, 2, 1, 'training']
# [122, 'two', 'O', 3, 2, 1, 'training']
# [123, 'or', 'O', 3, 2, 1, 'training']
# [124, 'more', 'O', 3, 2, 1, 'training']
# [125, 'different', 'O', 3, 2, 1, 'training']
# [126, 'depths', 'O', 3, 2, 1, 'training']
# [127, 'according', 'O', 3, 2, 1, 'training']
# [128, 'to', 'O', 3, 2, 1, 'training']
# [129, 'the', 'O', 3, 2, 1, 'training']
# [130, 'plurality', 'O', 3, 2, 1, 'training']
# [131, 'diffractive', 'O', 3, 2, 1, 'training']
# [132, 'elements', 'O', 3, 2, 1, 'training']
# [133, '.', 'O', 3, 2, 1, 'training']
# [134, 'Examples', 'O', 1, 3, 1, 'training']
# [135, 'described', 'O', 1, 3, 1, 'training']
# [136, 'herein', 'O', 1, 3, 1, 'training']
# [137, 'include', 'O', 1, 3, 1, 'training']
# [138, 'mobility', 'B-HARDWARE', 1, 3, 1, 'training']
# [139, 'devices', 'I-HARDWARE', 1, 3, 1, 'training']
# [140, 'that', 'O', 1, 3, 1, 'training']
# [141, 'may', 'O', 1, 3, 1, 'training']
# [142, 'include', 'O', 1, 3, 1, 'training']
# [143, 'a', 'O', 1, 3, 1, 'training']
# [144, 'variety', 'O', 1, 3, 1, 'training']
# [145, 'of', 'O', 1, 3, 1, 'training']
# [146, 'enhanced', 'O', 1, 3, 1, 'training']
# [147, 'features', 'O', 1, 3, 1, 'training']
# [148, '.', 'O', 1, 3, 1, 'training']
# [149, 'For', 'O', 2, 3, 1, 'training']
# [150, 'example', 'O', 2, 3, 1, 'training']
# [151, ',', 'O', 2, 3, 1, 'training']
# [152, 'mobility', 'B-HARDWARE', 2, 3, 1, 'training']
# [153, 'devices', 'I-HARDWARE', 2, 3, 1, 'training']
# [154, 'are', 'O', 2, 3, 1, 'training']
# [155, 'described', 'O', 2, 3, 1, 'training']
# [156, 'which', 'O', 2, 3, 1, 'training']
# [157, 'may', 'O', 2, 3, 1, 'training']
# [158, 'more', 'O', 2, 3, 1, 'training']
# [159, 'accurately', 'O', 2, 3, 1, 'training']
# [160, 'assess', 'B-FUNCIONALIDADE', 2, 3, 1, 'training']
# [161, 'a', 'I-FUNCIONALIDADE', 2, 3, 1, 'training']
# [162, 'fall', 'I-FUNCIONALIDADE', 2, 3, 1, 'training']
# [163, 'of', 'I-FUNCIONALIDADE', 2, 3, 1, 'training']
# [164, 'a', 'I-FUNCIONALIDADE', 2, 3, 1, 'training']
# [165, 'user', 'I-FUNCIONALIDADE', 2, 3, 1, 'training']
# [166, 'by', 'O', 2, 3, 1, 'training']
# [167, 'determining', 'O', 2, 3, 1, 'training']
# [168, 'if', 'O', 2, 3, 1, 'training']
# [169, 'a', 'O', 2, 3, 1, 'training']
# [170, 'user', 'B-PESSOA', 2, 3, 1, 'training']
# [171, 'is', 'O', 2, 3, 1, 'training']
# [172, 'in', 'O', 2, 3, 1, 'training']
# [173, 'proximity', 'O', 2, 3, 1, 'training']
# [174, 'to', 'O', 2, 3, 1, 'training']
# [175, 'a', 'O', 2, 3, 1, 'training']
# [176, 'portion', 'O', 2, 3, 1, 'training']
# [177, 'of', 'O', 2, 3, 1, 'training']
# [178, 'the', 'O', 2, 3, 1, 'training']
# [179, 'mobility', 'B-HARDWARE', 2, 3, 1, 'training']
# [180, 'device', 'I-HARDWARE', 2, 3, 1, 'training']
# [181, 'after', 'O', 2, 3, 1, 'training']
# [182, 'a', 'O', 2, 3, 1, 'training']
# [183, 'fall', 'O', 2, 3, 1, 'training']
# [184, 'of', 'O', 2, 3, 1, 'training']
# [185, 'the', 'O', 2, 3, 1, 'training']
# [186, 'mobility', 'B-HARDWARE', 2, 3, 1, 'training']
# [187, 'device', 'I-HARDWARE', 2, 3, 1, 'training']
# [188, 'is', 'O', 2, 3, 1, 'training']
# [189, 'detected', 'O', 2, 3, 1, 'training']
# [190, '.', 'O', 2, 3, 1, 'training']
# [191, 'Examples', 'O', 3, 3, 1, 'training']
# [192, 'of', 'O', 3, 3, 1, 'training']
# [193, 'wall', 'O', 3, 3, 1, 'training']
# [194, 'mounted', 'O', 3, 3, 1, 'training']
# [195, 'chargers', 'O', 3, 3, 1, 'training']
# [196, 'for', 'O', 3, 3, 1, 'training']
# [197, 'mobility', 'B-HARDWARE', 3, 3, 1, 'training']
# [198, 'devices', 'I-HARDWARE', 3, 3, 1, 'training']
# [199, 'are', 'O', 3, 3, 1, 'training']
# [200, 'also', 'O', 3, 3, 1, 'training']
# [201, 'described', 'O', 3, 3, 1, 'training']
# [202, '.', 'O', 3, 3, 1, 'training']
# [203, 'Moreover', 'O', 4, 3, 1, 'training']
# [204, ',', 'O', 4, 3, 1, 'training']
# [205, 'examples', 'O', 4, 3, 1, 'training']
# [206, 'of', 'O', 4, 3, 1, 'training']
# [207, 'mechanisms', 'O', 4, 3, 1, 'training']
# [208, 'for', 'O', 4, 3, 1, 'training']
# [209, 'detaching', 'O', 4, 3, 1, 'training']
# [210, 'and', 'O', 4, 3, 1, 'training']
# [211, 'attaching', 'O', 4, 3, 1, 'training']
# [212, 'tips', 'O', 4, 3, 1, 'training']
# [213, 'to', 'O', 4, 3, 1, 'training']
# [214, 'mobility', 'B-HARDWARE', 4, 3, 1, 'training']
# [215, 'devices', 'I-HARDWARE', 4, 3, 1, 'training']
# [216, '(', 'O', 4, 3, 1, 'training']
# [217, 'e', 'O', 4, 3, 1, 'training']
# [218, '.', 'O', 4, 3, 1, 'training']
# [219, 'g', 'O', 4, 3, 1, 'training']
# [220, '.', 'O', 4, 3, 1, 'training']
# [221, 'canes', 'O', 5, 3, 1, 'training']
# [222, ')', 'O', 5, 3, 1, 'training']
# [223, 'are', 'O', 5, 3, 1, 'training']
# [224, 'described', 'O', 5, 3, 1, 'training']
# [225, 'which', 'O', 5, 3, 1, 'training']
# [226, 'may', 'O', 5, 3, 1, 'training']
# [227, 'facilitate', 'O', 5, 3, 1, 'training']
# [228, 'swapping', 'O', 5, 3, 1, 'training']
# [229, 'of', 'O', 5, 3, 1, 'training']
# [230, 'different', 'O', 5, 3, 1, 'training']
# [231, 'tips', 'O', 5, 3, 1, 'training']
# [232, 'for', 'O', 5, 3, 1, 'training']
# [233, 'different', 'O', 5, 3, 1, 'training']
# [234, 'situations', 'O', 5, 3, 1, 'training']
# [235, '.', 'O', 5, 3, 1, 'training']
# [236, 'A', 'O', 1, 4, 1, 'training']
# [237, 'transportation', 'B-SOFTWARE', 1, 4, 1, 'training']
# [238, 'mobility', 'I-SOFTWARE', 1, 4, 1, 'training']
# [239, 'system', 'I-SOFTWARE', 1, 4, 1, 'training']
# [240, 'includes', 'O', 1, 4, 1, 'training']
# [241, 'a', 'O', 1, 4, 1, 'training']
# [242, 'data', 'B-HARDWARE', 1, 4, 1, 'training']
# [243, 'storage', 'I-HARDWARE', 1, 4, 1, 'training']
# [244, 'configured', 'O', 1, 4, 1, 'training']
# [245, 'to', 'O', 1, 4, 1, 'training']
# [246, 'maintain', 'B-FUNCIONALIDADE', 1, 4, 1, 'training']
# [247, 'vehicle', 'I-FUNCIONALIDADE', 1, 4, 1, 'training']
# [248, 'data', 'I-FUNCIONALIDADE', 1, 4, 1, 'training']
# [249, 'indicating', 'I-FUNCIONALIDADE', 1, 4, 1, 'training']
# [250, 'fuel', 'I-FUNCIONALIDADE', 1, 4, 1, 'training']
# [251, 'consumption', 'I-FUNCIONALIDADE', 1, 4, 1, 'training']
# [252, 'and', 'O', 1, 4, 1, 'training']
# [253, 'count', 'O', 1, 4, 1, 'training']
# [254, 'of', 'O', 1, 4, 1, 'training']
# [255, 'passengers', 'B-PESSOA', 1, 4, 1, 'training']
# [256, 'for', 'O', 1, 4, 1, 'training']
# [257, 'vehicles', 'O', 1, 4, 1, 'training']
# [258, 'of', 'O', 1, 4, 1, 'training']
# [259, 'a', 'O', 1, 4, 1, 'training']
# [260, 'transportation', 'O', 1, 4, 1, 'training']
# [261, 'system', 'O', 1, 4, 1, 'training']
# [262, ',', 'O', 1, 4, 1, 'training']
# [263, 'and', 'O', 1, 4, 1, 'training']
# [264, 'user', 'O', 1, 4, 1, 'training']
# [265, 'data', 'O', 1, 4, 1, 'training']
# [266, 'describing', 'O', 1, 4, 1, 'training']
# [267, 'movements', 'O', 1, 4, 1, 'training']
# [268, 'of', 'O', 1, 4, 1, 'training']
# [269, 'the', 'O', 1, 4, 1, 'training']
# [270, 'passengers', 'B-PESSOA', 1, 4, 1, 'training']
# [271, 'within', 'O', 1, 4, 1, 'training']
# [272, 'the', 'O', 1, 4, 1, 'training']
# [273, 'transportation', 'O', 1, 4, 1, 'training']
# [274, 'system', 'O', 1, 4, 1, 'training']
# [275, '.', 'O', 1, 4, 1, 'training']
# [276, 'The', 'O', 2, 4, 1, 'training']
# [277, 'system', 'O', 2, 4, 1, 'training']
# [278, 'also', 'O', 2, 4, 1, 'training']
# [279, 'includes', 'O', 2, 4, 1, 'training']
# [280, 'an', 'O', 2, 4, 1, 'training']
# [281, 'emissions', 'B-SOFTWARE', 2, 4, 1, 'training']
# [282, 'monitoring', 'I-SOFTWARE', 2, 4, 1, 'training']
# [283, 'portal', 'I-SOFTWARE', 2, 4, 1, 'training']
# [284, ',', 'O', 2, 4, 1, 'training']
# [285, 'programmed', 'O', 2, 4, 1, 'training']
# [286, 'to', 'O', 2, 4, 1, 'training']
# [287, 'provide', 'O', 2, 4, 1, 'training']
# [288, ',', 'O', 2, 4, 1, 'training']
# [289, 'for', 'O', 2, 4, 1, 'training']
# [290, 'vehicles', 'O', 2, 4, 1, 'training']
# [291, 'of', 'O', 2, 4, 1, 'training']
# [292, 'a', 'O', 2, 4, 1, 'training']
# [293, 'fleet', 'O', 2, 4, 1, 'training']
# [294, ',', 'O', 2, 4, 1, 'training']
# [295, 'estimates', 'O', 2, 4, 1, 'training']
# [296, 'of', 'O', 2, 4, 1, 'training']
# [297, 'pollutant', 'O', 2, 4, 1, 'training']
# [298, 'emissions', 'O', 2, 4, 1, 'training']
# [299, 'for', 'O', 2, 4, 1, 'training']
# [300, 'the', 'O', 2, 4, 1, 'training']
# [301, 'fleet', 'O', 2, 4, 1, 'training']
# [302, 'and', 'O', 2, 4, 1, 'training']
# [303, 'a', 'O', 2, 4, 1, 'training']
# [304, 'percent', 'O', 2, 4, 1, 'training']
# [305, 'share', 'O', 2, 4, 1, 'training']
# [306, 'of', 'O', 2, 4, 1, 'training']
# [307, 'miles', 'O', 2, 4, 1, 'training']
# [308, 'completed', 'O', 2, 4, 1, 'training']
# [309, 'by', 'O', 2, 4, 1, 'training']
# [310, 'zero', 'O', 2, 4, 1, 'training']
# [311, '-', 'O', 2, 4, 1, 'training']
# [312, 'emissions', 'O', 2, 4, 1, 'training']
# [313, 'transportation', 'O', 2, 4, 1, 'training']
# [314, 'for', 'O', 2, 4, 1, 'training']
# [315, 'the', 'O', 2, 4, 1, 'training']
# [316, 'fleet', 'O', 2, 4, 1, 'training']
# [317, '.', 'O', 2, 4, 1, 'training']
# [318, 'A', 'O', 1, 5, 1, 'training']
# [319, 'system', 'O', 1, 5, 1, 'training']
# [320, ',', 'O', 1, 5, 1, 'training']
# [321, 'method', 'O', 1, 5, 1, 'training']
# [322, ',', 'O', 1, 5, 1, 'training']
# [323, 'and', 'O', 1, 5, 1, 'training']
# [324, 'computer', 'B-SOFTWARE', 1, 5, 1, 'training']
# [325, 'program', 'I-SOFTWARE', 1, 5, 1, 'training']
# [326, 'product', 'I-SOFTWARE', 1, 5, 1, 'training']
# [327, 'are', 'O', 1, 5, 1, 'training']
# [328, 'provided', 'O', 1, 5, 1, 'training']
# [329, 'for', 'O', 1, 5, 1, 'training']
# [330, 'mitigation', 'O', 1, 5, 1, 'training']
# [331, 'of', 'O', 1, 5, 1, 'training']
# [332, 'user', 'O', 1, 5, 1, 'training']
# [333, '-', 'O', 1, 5, 1, 'training']
# [334, 'specific', 'O', 1, 5, 1, 'training']
# [335, 'ping', 'O', 1, 5, 1, 'training']
# [336, '-', 'O', 1, 5, 1, 'training']
# [337, 'pong', 'O', 1, 5, 1, 'training']
# [338, 'handover', 'O', 1, 5, 1, 'training']
# [339, '.', 'O', 1, 5, 1, 'training']
# [340, 'In', 'O', 2, 5, 1, 'training']
# [341, 'operation', 'O', 2, 5, 1, 'training']
# [342, ',', 'O', 2, 5, 1, 'training']
# [343, 'user', 'B-HARDWARE', 2, 5, 1, 'training']
# [344, 'equipment', 'I-HARDWARE', 2, 5, 1, 'training']
# [345, '(', 'I-HARDWARE', 2, 5, 1, 'training']
# [346, 'UE', 'I-HARDWARE', 2, 5, 1, 'training']
# [347, ')', 'I-HARDWARE', 2, 5, 1, 'training']
# [348, 'monitors', 'I-HARDWARE', 2, 5, 1, 'training']
# [349, 'for', 'O', 2, 5, 1, 'training']
# [350, 'a', 'O', 2, 5, 1, 'training']
# [351, 'ping', 'O', 2, 5, 1, 'training']
# [352, '-', 'O', 2, 5, 1, 'training']
# [353, 'pong', 'O', 2, 5, 1, 'training']
# [354, 'handover', 'O', 2, 5, 1, 'training']
# [355, 'scenario', 'O', 2, 5, 1, 'training']
# [356, 'between', 'O', 2, 5, 1, 'training']
# [357, 'the', 'O', 2, 5, 1, 'training']
# [358, 'UE', 'O', 2, 5, 1, 'training']
# [359, 'and', 'O', 2, 5, 1, 'training']
# [360, 'a', 'O', 2, 5, 1, 'training']
# [361, 'plurality', 'O', 2, 5, 1, 'training']
# [362, 'of', 'O', 2, 5, 1, 'training']
# [363, 'nodes', 'O', 2, 5, 1, 'training']
# [364, 'in', 'O', 2, 5, 1, 'training']
# [365, 'a', 'O', 2, 5, 1, 'training']
# [366, 'wireless', 'B-COMUNICAÇÃO', 2, 5, 1, 'training']
# [367, 'communication', 'I-COMUNICAÇÃO', 2, 5, 1, 'training']
# [368, 'network', 'I-COMUNICAÇÃO', 2, 5, 1, 'training']
# [369, '.', 'O', 2, 5, 1, 'training']
# [370, 'The', 'O', 3, 5, 1, 'training']
# [371, 'UE', 'O', 3, 5, 1, 'training']
# [372, 'determines', 'B-FUNCIONALIDADE', 3, 5, 1, 'training']
# [373, 'whether', 'I-FUNCIONALIDADE', 3, 5, 1, 'training']
# [374, 'a', 'I-FUNCIONALIDADE', 3, 5, 1, 'training']
# [375, 'state', 'I-FUNCIONALIDADE', 3, 5, 1, 'training']
# [376, 'of', 'I-FUNCIONALIDADE', 3, 5, 1, 'training']
# [377, 'the', 'I-FUNCIONALIDADE', 3, 5, 1, 'training']
# [378, 'UE', 'I-FUNCIONALIDADE', 3, 5, 1, 'training']
# [379, 'is', 'I-FUNCIONALIDADE', 3, 5, 1, 'training']
# [380, 'static', 'I-FUNCIONALIDADE', 3, 5, 1, 'training']
# [381, ',', 'O', 3, 5, 1, 'training']
# [382, 'if', 'O', 3, 5, 1, 'training']
# [383, 'it', 'O', 3, 5, 1, 'training']
# [384, 'is', 'O', 3, 5, 1, 'training']
# [385, 'determined', 'O', 3, 5, 1, 'training']
# [386, 'that', 'O', 3, 5, 1, 'training']
# [387, 'the', 'O', 3, 5, 1, 'training']
# [388, 'UE', 'O', 3, 5, 1, 'training']
# [389, 'is', 'O', 3, 5, 1, 'training']
# [390, 'experiencing', 'O', 3, 5, 1, 'training']
# [391, 'a', 'O', 3, 5, 1, 'training']
# [392, 'ping', 'O', 3, 5, 1, 'training']
# [393, '-', 'O', 3, 5, 1, 'training']
# [394, 'pong', 'O', 3, 5, 1, 'training']
# [395, 'handover', 'O', 3, 5, 1, 'training']
# [396, 'scenario', 'O', 3, 5, 1, 'training']
# [397, '.', 'O', 3, 5, 1, 'training']
# [398, 'The', 'O', 4, 5, 1, 'training']
# [399, 'UE', 'O', 4, 5, 1, 'training']
# [400, 'receives', 'B-FUNCIONALIDADE', 4, 5, 1, 'training']
# [401, 'a', 'I-FUNCIONALIDADE', 4, 5, 1, 'training']
# [402, 'deferred', 'I-FUNCIONALIDADE', 4, 5, 1, 'training']
# [403, 'measurement', 'I-FUNCIONALIDADE', 4, 5, 1, 'training']
# [404, 'time', 'I-FUNCIONALIDADE', 4, 5, 1, 'training']
# [405, 'indicator', 'I-FUNCIONALIDADE', 4, 5, 1, 'training']
# [406, 'from', 'O', 4, 5, 1, 'training']
# [407, 'a', 'O', 4, 5, 1, 'training']
# [408, 'best', 'O', 4, 5, 1, 'training']
# [409, 'serving', 'O', 4, 5, 1, 'training']
# [410, 'node', 'O', 4, 5, 1, 'training']
# [411, 'of', 'O', 4, 5, 1, 'training']
# [412, 'the', 'O', 4, 5, 1, 'training']
# [413, 'plurality', 'O', 4, 5, 1, 'training']
# [414, 'of', 'O', 4, 5, 1, 'training']
# [415, 'nodes', 'O', 4, 5, 1, 'training']
# [416, ',', 'O', 4, 5, 1, 'training']
# [417, 'if', 'O', 4, 5, 1, 'training']
# [418, 'it', 'O', 4, 5, 1, 'training']
# [419, 'is', 'O', 4, 5, 1, 'training']
# [420, 'determined', 'O', 4, 5, 1, 'training']
# [421, 'that', 'O', 4, 5, 1, 'training']
# [422, 'the', 'O', 4, 5, 1, 'training']
# [423, 'state', 'O', 4, 5, 1, 'training']
# [424, 'of', 'O', 4, 5, 1, 'training']
# [425, 'the', 'O', 4, 5, 1, 'training']
# [426, 'UE', 'O', 4, 5, 1, 'training']
# [427, 'is', 'O', 4, 5, 1, 'training']
# [428, 'static', 'O', 4, 5, 1, 'training']
# [429, '.', 'O', 4, 5, 1, 'training']
# [430, 'The', 'O', 5, 5, 1, 'training']
# [431, 'UE', 'O', 5, 5, 1, 'training']
# [432, 'defers', 'O', 5, 5, 1, 'training']
# [433, 'sending', 'O', 5, 5, 1, 'training']
# [434, 'a', 'O', 5, 5, 1, 'training']
# [435, 'measurement', 'O', 5, 5, 1, 'training']
# [436, 'report', 'O', 5, 5, 1, 'training']
# [437, 'to', 'O', 5, 5, 1, 'training']
# [438, 'the', 'O', 5, 5, 1, 'training']
# [439, 'plurality', 'O', 5, 5, 1, 'training']
# [440, 'of', 'O', 5, 5, 1, 'training']
# [441, 'nodes', 'O', 5, 5, 1, 'training']
# [442, 'for', 'O', 5, 5, 1, 'training']
# [443, 'a', 'O', 5, 5, 1, 'training']
# [444, 'time', 'O', 5, 5, 1, 'training']
# [445, '-', 'O', 5, 5, 1, 'training']
# [446, 'period', 'O', 5, 5, 1, 'training']
# [447, 'associated', 'O', 5, 5, 1, 'training']
# [448, 'with', 'O', 5, 5, 1, 'training']
# [449, 'the', 'O', 5, 5, 1, 'training']
# [450, 'deferred', 'O', 5, 5, 1, 'training']
# [451, 'measurement', 'O', 5, 5, 1, 'training']
# [452, 'time', 'O', 5, 5, 1, 'training']
# [453, 'indicator', 'O', 5, 5, 1, 'training']
# [454, '.', 'O', 5, 5, 1, 'training']
# [455, 'One', 'O', 1, 6, 1, 'training']
# [456, 'or', 'O', 1, 6, 1, 'training']
# [457, 'more', 'O', 1, 6, 1, 'training']
# [458, 'protocols', 'B-SOFTWARE', 1, 6, 1, 'training']
# [459, 'between', 'I-SOFTWARE', 1, 6, 1, 'training']
# [460, 'a', 'I-SOFTWARE', 1, 6, 1, 'training']
# [461, 'control', 'I-SOFTWARE', 1, 6, 1, 'training']
# [462, 'plane', 'I-SOFTWARE', 1, 6, 1, 'training']
# [463, 'entity', 'I-SOFTWARE', 1, 6, 1, 'training']
# [464, '(', 'O', 1, 6, 1, 'training']
# [465, 'e', 'O', 1, 6, 1, 'training']
# [466, '.', 'O', 1, 6, 1, 'training']
# [467, 'g', 'O', 1, 6, 1, 'training']
# [468, '.', 'O', 1, 6, 1, 'training']
# [469, ',', 'O', 1, 6, 1, 'training']
# [470, 'a', 'O', 1, 6, 1, 'training']
# [471, 'mobility', 'B-SOFTWARE', 1, 6, 1, 'training']
# [472, 'management', 'I-SOFTWARE', 1, 6, 1, 'training']
# [473, 'entity', 'I-SOFTWARE', 1, 6, 1, 'training']
# [474, '(', 'O', 1, 6, 1, 'training']
# [475, 'MME', 'O', 1, 6, 1, 'training']
# [476, ')', 'O', 1, 6, 1, 'training']
# [477, ')', 'O', 1, 6, 1, 'training']
# [478, 'and', 'O', 1, 6, 1, 'training']
# [479, 'its', 'O', 1, 6, 1, 'training']
# [480, 'peer', 'O', 1, 6, 1, 'training']
# [481, 'nodes', 'O', 1, 6, 1, 'training']
# [482, '(', 'O', 1, 6, 1, 'training']
# [483, 'e', 'O', 1, 6, 1, 'training']
# [484, '.', 'O', 1, 6, 1, 'training']
# [485, 'g', 'O', 1, 6, 1, 'training']
# [486, '.', 'O', 1, 6, 1, 'training']
# [487, ',', 'O', 1, 6, 1, 'training']
# [488, 'mobile', 'B-SOFTWARE', 1, 6, 1, 'training']
# [489, 'switching', 'I-SOFTWARE', 1, 6, 1, 'training']
# [490, 'center', 'I-SOFTWARE', 1, 6, 1, 'training']
# [491, '(', 'O', 1, 6, 1, 'training']
# [492, 'MSC', 'O', 1, 6, 1, 'training']
# [493, ')', 'O', 1, 6, 1, 'training']
# [494, 'and', 'O', 1, 6, 1, 'training']
# [495, '/', 'O', 1, 6, 1, 'training']
# [496, 'or', 'O', 1, 6, 1, 'training']
# [497, 'short', 'B-SOFTWARE', 1, 6, 1, 'training']
# [498, 'message', 'I-SOFTWARE', 1, 6, 1, 'training']
# [499, 'service', 'I-SOFTWARE', 1, 6, 1, 'training']
# [500, 'center', 'I-SOFTWARE', 1, 6, 1, 'training']
# [501, '(', 'O', 1, 6, 1, 'training']
# [502, 'SMSC', 'O', 1, 6, 1, 'training']
# [503, ')', 'O', 1, 6, 1, 'training']
# [504, ')', 'O', 1, 6, 1, 'training']
# [505, 'are', 'O', 1, 6, 1, 'training']
# [506, 'enhanced', 'O', 1, 6, 1, 'training']
# [507, 'to', 'O', 1, 6, 1, 'training']
# [508, 'improve', 'B-FUNCIONALIDADE', 1, 6, 1, 'training']
# [509, 'short', 'I-FUNCIONALIDADE', 1, 6, 1, 'training']
# [510, 'messaging', 'I-FUNCIONALIDADE', 1, 6, 1, 'training']
# [511, 'services', 'I-FUNCIONALIDADE', 1, 6, 1, 'training']
# [512, 'for', 'O', 1, 6, 1, 'training']
# [513, 'Internet', 'B-HARDWARE', 1, 6, 1, 'training']
# [514, 'of', 'I-HARDWARE', 1, 6, 1, 'training']
# [515, 'things', 'I-HARDWARE', 1, 6, 1, 'training']
# [516, '(', 'I-HARDWARE', 1, 6, 1, 'training']
# [517, 'IoT', 'I-HARDWARE', 1, 6, 1, 'training']
# [518, ')', 'I-HARDWARE', 1, 6, 1, 'training']
# [519, 'devices', 'I-HARDWARE', 1, 6, 1, 'training']
# [520, '.', 'O', 1, 6, 1, 'training']
# [521, 'Oftentimes', 'O', 2, 6, 1, 'training']
# [522, ',', 'O', 2, 6, 1, 'training']
# [523, 'IoT', 'B-HARDWARE', 2, 6, 1, 'training']
# [524, 'devices', 'I-HARDWARE', 2, 6, 1, 'training']
# [525, 'enter', 'O', 2, 6, 1, 'training']
# [526, 'an', 'O', 2, 6, 1, 'training']
# [527, 'extended', 'O', 2, 6, 1, 'training']
# [528, 'sleep', 'O', 2, 6, 1, 'training']
# [529, 'mode', 'O', 2, 6, 1, 'training']
# [530, 'during', 'O', 2, 6, 1, 'training']
# [531, 'which', 'O', 2, 6, 1, 'training']
# [532, 'they', 'O', 2, 6, 1, 'training']
# [533, 'cannot', 'O', 2, 6, 1, 'training']
# [534, 'be', 'O', 2, 6, 1, 'training']
# [535, 'reached', 'O', 2, 6, 1, 'training']
# [536, 'by', 'O', 2, 6, 1, 'training']
# [537, 'the', 'O', 2, 6, 1, 'training']
# [538, 'control', 'O', 2, 6, 1, 'training']
# [539, 'plane', 'O', 2, 6, 1, 'training']
# [540, 'entity', 'O', 2, 6, 1, 'training']
# [541, '.', 'O', 2, 6, 1, 'training']
# [542, 'In', 'O', 3, 6, 1, 'training']
# [543, 'one', 'O', 3, 6, 1, 'training']
# [544, 'aspect', 'O', 3, 6, 1, 'training']
# [545, ',', 'O', 3, 6, 1, 'training']
# [546, 'the', 'O', 3, 6, 1, 'training']
# [547, 'control', 'O', 3, 6, 1, 'training']
# [548, 'plane', 'O', 3, 6, 1, 'training']
# [549, 'entity', 'O', 3, 6, 1, 'training']
# [550, 'can', 'O', 3, 6, 1, 'training']
# [551, 'determine', 'B-FUNCIONALIDADE', 3, 6, 1, 'training']
# [552, 'a', 'I-FUNCIONALIDADE', 3, 6, 1, 'training']
# [553, 'wait', 'I-FUNCIONALIDADE', 3, 6, 1, 'training']
# [554, 'period', 'I-FUNCIONALIDADE', 3, 6, 1, 'training']
# [555, 'based', 'O', 3, 6, 1, 'training']
# [556, 'on', 'O', 3, 6, 1, 'training']
# [557, 'information', 'O', 3, 6, 1, 'training']
# [558, ',', 'O', 3, 6, 1, 'training']
# [559, 'such', 'O', 3, 6, 1, 'training']
# [560, 'as', 'O', 3, 6, 1, 'training']
# [561, ',', 'O', 3, 6, 1, 'training']
# [562, 'but', 'O', 3, 6, 1, 'training']
# [563, 'not', 'O', 3, 6, 1, 'training']
# [564, 'limited', 'O', 3, 6, 1, 'training']
# [565, 'to', 'O', 3, 6, 1, 'training']
# [566, ',', 'O', 3, 6, 1, 'training']
# [567, 'device', 'O', 3, 6, 1, 'training']
# [568, 'context', 'O', 3, 6, 1, 'training']
# [569, 'data', 'O', 3, 6, 1, 'training']
# [570, ',', 'O', 3, 6, 1, 'training']
# [571, 'mapping', 'O', 3, 6, 1, 'training']
# [572, 'tables', 'O', 3, 6, 1, 'training']
# [573, ',', 'O', 3, 6, 1, 'training']
# [574, 'policy', 'O', 3, 6, 1, 'training']
# [575, 'data', 'O', 3, 6, 1, 'training']
# [576, ',', 'O', 3, 6, 1, 'training']
# [577, 'commercial', 'O', 3, 6, 1, 'training']
# [578, 'traffic', 'O', 3, 6, 1, 'training']
# [579, 'data', 'O', 3, 6, 1, 'training']
# [580, ',', 'O', 3, 6, 1, 'training']
# [581, 'latency', 'O', 3, 6, 1, 'training']
# [582, 'data', 'O', 3, 6, 1, 'training']
# [583, ',', 'O', 3, 6, 1, 'training']
# [584, 'device', 'O', 3, 6, 1, 'training']
# [585, 'delay', 'O', 3, 6, 1, 'training']
# [586, 'tolerance', 'O', 3, 6, 1, 'training']
# [587, ',', 'O', 3, 6, 1, 'training']
# [588, 'sleep', 'O', 3, 6, 1, 'training']
# [589, 'mode', 'O', 3, 6, 1, 'training']
# [590, 'timer', 'O', 3, 6, 1, 'training']
# [591, 'values', 'O', 3, 6, 1, 'training']
# [592, ',', 'O', 3, 6, 1, 'training']
# [593, 'etc', 'O', 3, 6, 1, 'training']
# [594, '.', 'O', 3, 6, 1, 'training']
# [595, 'The', 'O', 4, 6, 1, 'training']
# [596, 'wait', 'O', 4, 6, 1, 'training']
# [597, 'period', 'O', 4, 6, 1, 'training']
# [598, 'can', 'O', 4, 6, 1, 'training']
# [599, 'be', 'O', 4, 6, 1, 'training']
# [600, 'provided', 'O', 4, 6, 1, 'training']
# [601, 'to', 'O', 4, 6, 1, 'training']
# [602, 'the', 'O', 4, 6, 1, 'training']
# [603, 'peer', 'O', 4, 6, 1, 'training']
# [604, 'nodes', 'O', 4, 6, 1, 'training']
# [605, ',', 'O', 4, 6, 1, 'training']
# [606, 'which', 'O', 4, 6, 1, 'training']
# [607, 'can', 'O', 4, 6, 1, 'training']
# [608, 'utilize', 'O', 4, 6, 1, 'training']
# [609, 'the', 'O', 4, 6, 1, 'training']
# [610, 'wait', 'O', 4, 6, 1, 'training']
# [611, 'period', 'O', 4, 6, 1, 'training']
# [612, 'to', 'O', 4, 6, 1, 'training']
# [613, 'control', 'B-FUNCIONALIDADE', 4, 6, 1, 'training']
# [614, 'one', 'I-FUNCIONALIDADE', 4, 6, 1, 'training']
# [615, 'or', 'I-FUNCIONALIDADE', 4, 6, 1, 'training']
# [616, 'more', 'I-FUNCIONALIDADE', 4, 6, 1, 'training']
# [617, 'message', 'I-FUNCIONALIDADE', 4, 6, 1, 'training']
# [618, 'retry', 'I-FUNCIONALIDADE', 4, 6, 1, 'training']
# [619, 'mechanisms', 'I-FUNCIONALIDADE', 4, 6, 1, 'training']
# [620, 'based', 'O', 4, 6, 1, 'training']
# [621, 'on', 'O', 4, 6, 1, 'training']
# [622, 'IoT', 'B-HARDWARE', 4, 6, 1, 'training']
# [623, 'device', 'I-HARDWARE', 4, 6, 1, 'training']
# [624, 'behaviors', 'O', 4, 6, 1, 'training']
# [625, 'resulting', 'O', 4, 6, 1, 'training']
# [626, 'in', 'O', 4, 6, 1, 'training']
# [627, 'an', 'O', 4, 6, 1, 'training']
# [628, 'improvement', 'O', 4, 6, 1, 'training']
# [629, 'of', 'O', 4, 6, 1, 'training']
# [630, 'overall', 'O', 4, 6, 1, 'training']
# [631, 'IoT', 'B-COMUNICAÇÃO', 4, 6, 1, 'training']
# [632, 'service', 'I-COMUNICAÇÃO', 4, 6, 1, 'training']
# [633, 'behaviors', 'O', 4, 6, 1, 'training']
# [634, 'and', 'O', 4, 6, 1, 'training']
# [635, 'a', 'O', 4, 6, 1, 'training']
# [636, 'delivery', 'O', 4, 6, 1, 'training']
# [637, 'of', 'O', 4, 6, 1, 'training']
# [638, 'superior', 'O', 4, 6, 1, 'training']
# [639, 'IoT', 'O', 4, 6, 1, 'training']
# [640, 'customer', 'O', 4, 6, 1, 'training']
# [641, 'experience', 'O', 4, 6, 1, 'training']
# [642, '.', 'O', 4, 6, 1, 'training']
# [643, 'An', 'O', 1, 7, 1, 'training']
# [644, 'interactive', 'O', 1, 7, 1, 'training']
# [645, ',', 'O', 1, 7, 1, 'training']
# [646, 'electronic', 'B-COMUNICAÇÃO', 1, 7, 1, 'training']
# [647, 'network', 'I-COMUNICAÇÃO', 1, 7, 1, 'training']
# [648, 'that', 'O', 1, 7, 1, 'training']
# [649, 'enables', 'B-FUNCIONALIDADE', 1, 7, 1, 'training']
# [650, 'multi', 'I-FUNCIONALIDADE', 1, 7, 1, 'training']
# [651, '-', 'I-FUNCIONALIDADE', 1, 7, 1, 'training']
# [652, 'level', 'I-FUNCIONALIDADE', 1, 7, 1, 'training']
# [653, 'control', 'I-FUNCIONALIDADE', 1, 7, 1, 'training']
# [654, ',', 'O', 1, 7, 1, 'training']
# [655, 'variable', 'O', 1, 7, 1, 'training']
# [656, 'access', 'O', 1, 7, 1, 'training']
# [657, ',', 'O', 1, 7, 1, 'training']
# [658, 'multi', 'O', 1, 7, 1, 'training']
# [659, '-', 'O', 1, 7, 1, 'training']
# [660, 'user', 'O', 1, 7, 1, 'training']
# [661, 'communications', 'O', 1, 7, 1, 'training']
# [662, 'of', 'O', 1, 7, 1, 'training']
# [663, 'real', 'O', 1, 7, 1, 'training']
# [664, '-', 'O', 1, 7, 1, 'training']
# [665, 'time', 'O', 1, 7, 1, 'training']
# [666, 'contextually', 'O', 1, 7, 1, 'training']
# [667, 'relevant', 'O', 1, 7, 1, 'training']
# [668, 'data', 'O', 1, 7, 1, 'training']
# [669, 'or', 'O', 1, 7, 1, 'training']
# [670, 'information', 'O', 1, 7, 1, 'training']
# [671, 'among', 'O', 1, 7, 1, 'training']
# [672, 'network', 'B-HARDWARE', 1, 7, 1, 'training']
# [673, '-', 'I-HARDWARE', 1, 7, 1, 'training']
# [674, 'connected', 'I-HARDWARE', 1, 7, 1, 'training']
# [675, 'devices', 'I-HARDWARE', 1, 7, 1, 'training']
# [676, ',', 'O', 1, 7, 1, 'training']
# [677, 'and', 'O', 1, 7, 1, 'training']
# [678, 'actions', 'O', 1, 7, 1, 'training']
# [679, 'based', 'O', 1, 7, 1, 'training']
# [680, 'on', 'O', 1, 7, 1, 'training']
# [681, 'those', 'O', 1, 7, 1, 'training']
# [682, 'communications', 'O', 1, 7, 1, 'training']
# [683, ',', 'O', 1, 7, 1, 'training']
# [684, 'as', 'O', 1, 7, 1, 'training']
# [685, 'the', 'O', 1, 7, 1, 'training']
# [686, 'network', 'B-HARDWARE', 1, 7, 1, 'training']
# [687, '-', 'I-HARDWARE', 1, 7, 1, 'training']
# [688, 'connected', 'I-HARDWARE', 1, 7, 1, 'training']
# [689, 'devices', 'I-HARDWARE', 1, 7, 1, 'training']
# [690, 'move', 'O', 1, 7, 1, 'training']
# [691, 'from', 'O', 1, 7, 1, 'training']
# [692, 'one', 'O', 1, 7, 1, 'training']
# [693, 'location', 'O', 1, 7, 1, 'training']
# [694, 'to', 'O', 1, 7, 1, 'training']
# [695, 'another', 'O', 1, 7, 1, 'training']
# [696, 'and', 'O', 1, 7, 1, 'training']
# [697, '/', 'O', 1, 7, 1, 'training']
# [698, 'or', 'O', 1, 7, 1, 'training']
# [699, 'the', 'O', 1, 7, 1, 'training']
# [700, 'data', 'O', 1, 7, 1, 'training']
# [701, '/', 'O', 1, 7, 1, 'training']
# [702, 'information', 'O', 1, 7, 1, 'training']
# [703, 'flow', 'O', 1, 7, 1, 'training']
# [704, 'among', 'O', 1, 7, 1, 'training']
# [705, 'those', 'O', 1, 7, 1, 'training']
# [706, 'devices', 'O', 1, 7, 1, 'training']
# [707, 'change', 'O', 1, 7, 1, 'training']
# [708, 'over', 'O', 1, 7, 1, 'training']
# [709, 'time', 'O', 1, 7, 1, 'training']
# [710, '.', 'O', 1, 7, 1, 'training']
# [711, 'Embodiments', 'O', 1, 8, 1, 'training']
# [712, 'of', 'O', 1, 8, 1, 'training']
# [713, 'a', 'O', 1, 8, 1, 'training']
# [714, 'smart', 'B-HARDWARE', 1, 8, 1, 'training']
# [715, 'mobility', 'I-HARDWARE', 1, 8, 1, 'training']
# [716, 'aid', 'I-HARDWARE', 1, 8, 1, 'training']
# [717, 'device', 'I-HARDWARE', 1, 8, 1, 'training']
# [718, 'may', 'O', 1, 8, 1, 'training']
# [719, 'have', 'O', 1, 8, 1, 'training']
# [720, 'sensors', 'B-HARDWARE', 1, 8, 1, 'training']
# [721, 'to', 'O', 1, 8, 1, 'training']
# [722, 'collect', 'O', 1, 8, 1, 'training']
# [723, ',', 'O', 1, 8, 1, 'training']
# [724, 'monitor', 'O', 1, 8, 1, 'training']
# [725, ',', 'O', 1, 8, 1, 'training']
# [726, 'analyze', 'O', 1, 8, 1, 'training']
# [727, 'and', 'O', 1, 8, 1, 'training']
# [728, 'represent', 'B-FUNCIONALIDADE', 1, 8, 1, 'training']
# [729, 'data', 'I-FUNCIONALIDADE', 1, 8, 1, 'training']
# [730, 'including', 'O', 1, 8, 1, 'training']
# [731, 'but', 'O', 1, 8, 1, 'training']
# [732, 'not', 'O', 1, 8, 1, 'training']
# [733, 'limited', 'O', 1, 8, 1, 'training']
# [734, 'to', 'O', 1, 8, 1, 'training']
# [735, 'activity', 'O', 1, 8, 1, 'training']
# [736, 'tracking', 'O', 1, 8, 1, 'training']
# [737, ',', 'O', 1, 8, 1, 'training']
# [738, 'biometrics', 'O', 1, 8, 1, 'training']
# [739, 'and', 'O', 1, 8, 1, 'training']
# [740, 'safety', 'O', 1, 8, 1, 'training']
# [741, 'and', 'O', 1, 8, 1, 'training']
# [742, 'emergency', 'O', 1, 8, 1, 'training']
# [743, 'features', 'O', 1, 8, 1, 'training']
# [744, '.', 'O', 1, 8, 1, 'training']
# [745, 'The', 'O', 2, 8, 1, 'training']
# [746, 'activity', 'O', 2, 8, 1, 'training']
# [747, 'tracking', 'O', 2, 8, 1, 'training']
# [748, 'include', 'O', 2, 8, 1, 'training']
# [749, 'number', 'O', 2, 8, 1, 'training']
# [750, 'of', 'O', 2, 8, 1, 'training']
# [751, 'steps', 'O', 2, 8, 1, 'training']
# [752, ',', 'O', 2, 8, 1, 'training']
# [753, 'miles', 'O', 2, 8, 1, 'training']
# [754, ',', 'O', 2, 8, 1, 'training']
# [755, 'and', 'O', 2, 8, 1, 'training']
# [756, 'activity', 'O', 2, 8, 1, 'training']
# [757, 'speed', 'O', 2, 8, 1, 'training']
# [758, ',', 'O', 2, 8, 1, 'training']
# [759, 'user', 'O', 2, 8, 1, 'training']
# [760, 'pressure', 'O', 2, 8, 1, 'training']
# [761, 'on', 'O', 2, 8, 1, 'training']
# [762, 'a', 'O', 2, 8, 1, 'training']
# [763, 'device', 'O', 2, 8, 1, 'training']
# [764, ',', 'O', 2, 8, 1, 'training']
# [765, 'activity', 'O', 2, 8, 1, 'training']
# [766, 'types', 'O', 2, 8, 1, 'training']
# [767, 'and', 'O', 2, 8, 1, 'training']
# [768, 'analysis', 'O', 2, 8, 1, 'training']
# [769, '.', 'O', 2, 8, 1, 'training']
# [770, 'The', 'O', 3, 8, 1, 'training']
# [771, 'user', 'O', 3, 8, 1, 'training']
# [772, 'biometric', 'O', 3, 8, 1, 'training']
# [773, 'data', 'O', 3, 8, 1, 'training']
# [774, 'includes', 'O', 3, 8, 1, 'training']
# [775, 'but', 'O', 3, 8, 1, 'training']
# [776, 'is', 'O', 3, 8, 1, 'training']
# [777, 'not', 'O', 3, 8, 1, 'training']
# [778, 'limited', 'O', 3, 8, 1, 'training']
# [779, 'to', 'O', 3, 8, 1, 'training']
# [780, 'blood', 'O', 3, 8, 1, 'training']
# [781, 'work', 'O', 3, 8, 1, 'training']
# [782, ',', 'O', 3, 8, 1, 'training']
# [783, 'blood', 'O', 3, 8, 1, 'training']
# [784, 'pressure', 'O', 3, 8, 1, 'training']
# [785, ',', 'O', 3, 8, 1, 'training']
# [786, 'blood', 'O', 3, 8, 1, 'training']
# [787, 'sugar', 'O', 3, 8, 1, 'training']
# [788, ',', 'O', 3, 8, 1, 'training']
# [789, 'heart', 'O', 3, 8, 1, 'training']
# [790, 'rate', 'O', 3, 8, 1, 'training']
# [791, ',', 'O', 3, 8, 1, 'training']
# [792, 'oxygen', 'O', 3, 8, 1, 'training']
# [793, 'level', 'O', 3, 8, 1, 'training']
# [794, '/', 'O', 3, 8, 1, 'training']
# [795, 'rate', 'O', 3, 8, 1, 'training']
# [796, ',', 'O', 3, 8, 1, 'training']
# [797, 'ECG', 'O', 3, 8, 1, 'training']
# [798, ',', 'O', 3, 8, 1, 'training']
# [799, 'EMG', 'O', 3, 8, 1, 'training']
# [800, ',', 'O', 3, 8, 1, 'training']
# [801, 'muscle', 'O', 3, 8, 1, 'training']
# [802, 'strain', 'O', 3, 8, 1, 'training']
# [803, ',', 'O', 3, 8, 1, 'training']
# [804, 'humidity', 'O', 3, 8, 1, 'training']
# [805, ',', 'O', 3, 8, 1, 'training']
# [806, 'UV', 'O', 3, 8, 1, 'training']
# [807, ',', 'O', 3, 8, 1, 'training']
# [808, 'body', 'O', 3, 8, 1, 'training']
# [809, 'temperature', 'O', 3, 8, 1, 'training']
# [810, '.', 'O', 3, 8, 1, 'training']
# [811, 'Additional', 'O', 4, 8, 1, 'training']
# [812, 'features', 'O', 4, 8, 1, 'training']
# [813, 'include', 'O', 4, 8, 1, 'training']
# [814, 'an', 'O', 4, 8, 1, 'training']
# [815, 'emergency', 'O', 4, 8, 1, 'training']
# [816, 'button', 'O', 4, 8, 1, 'training']
# [817, ',', 'O', 4, 8, 1, 'training']
# [818, 'fall', 'O', 4, 8, 1, 'training']
# [819, 'detection', 'O', 4, 8, 1, 'training']
# [820, ',', 'O', 4, 8, 1, 'training']
# [821, 'warnings', 'O', 4, 8, 1, 'training']
# [822, ',', 'O', 4, 8, 1, 'training']
# [823, 'and', 'O', 4, 8, 1, 'training']
# [824, 'user', 'O', 4, 8, 1, 'training']
# [825, 'pattern', 'O', 4, 8, 1, 'training']
# [826, 'analysis', 'O', 4, 8, 1, 'training']
# [827, 'changes', 'O', 4, 8, 1, 'training']
# [828, '.', 'O', 4, 8, 1, 'training']
# [829, 'The', 'O', 5, 8, 1, 'training']
# [830, 'mobility', 'B-HARDWARE', 5, 8, 1, 'training']
# [831, 'aid', 'I-HARDWARE', 5, 8, 1, 'training']
# [832, 'device', 'I-HARDWARE', 5, 8, 1, 'training']
# [833, 'is', 'O', 5, 8, 1, 'training']
# [834, 'connected', 'O', 5, 8, 1, 'training']
# [835, 'to', 'O', 5, 8, 1, 'training']
# [836, 'other', 'O', 5, 8, 1, 'training']
# [837, 'smart', 'B-HARDWARE', 5, 8, 1, 'training']
# [838, 'electronic', 'I-HARDWARE', 5, 8, 1, 'training']
# [839, 'devices', 'I-HARDWARE', 5, 8, 1, 'training']
# [840, 'and', 'O', 5, 8, 1, 'training']
# [841, '/', 'O', 5, 8, 1, 'training']
# [842, 'or', 'O', 5, 8, 1, 'training']
# [843, 'the', 'O', 5, 8, 1, 'training']
# [844, 'Internet', 'B-COMUNICAÇÃO', 5, 8, 1, 'training']
# [845, 'using', 'O', 5, 8, 1, 'training']
# [846, 'but', 'O', 5, 8, 1, 'training']
# [847, 'not', 'O', 5, 8, 1, 'training']
# [848, 'limited', 'O', 5, 8, 1, 'training']
# [849, 'to', 'O', 5, 8, 1, 'training']
# [850, 'Bluetooth', 'B-COMUNICAÇÃO', 5, 8, 1, 'training']
# [851, ',', 'O', 5, 8, 1, 'training']
# [852, 'Wi', 'B-COMUNICAÇÃO', 5, 8, 1, 'training']
# [853, '-', 'I-COMUNICAÇÃO', 5, 8, 1, 'training']
# [854, 'Fi', 'I-COMUNICAÇÃO', 5, 8, 1, 'training']
# [855, ',', 'O', 5, 8, 1, 'training']
# [856, 'and', 'O', 5, 8, 1, 'training']
# [857, 'or', 'O', 5, 8, 1, 'training']
# [858, '/', 'O', 5, 8, 1, 'training']
# [859, 'and', 'O', 5, 8, 1, 'training']
# [860, 'SIM', 'B-HARDWARE', 5, 8, 1, 'training']
# [861, 'card', 'I-HARDWARE', 5, 8, 1, 'training']
# [862, '.', 'O', 5, 8, 1, 'training']
# [863, 'The', 'O', 6, 8, 1, 'training']
# [864, 'device', 'O', 6, 8, 1, 'training']
# [865, 'gives', 'B-FUNCIONALIDADE', 6, 8, 1, 'training']
# [866, 'the', 'I-FUNCIONALIDADE', 6, 8, 1, 'training']
# [867, 'user', 'I-FUNCIONALIDADE', 6, 8, 1, 'training']
# [868, 'or', 'I-FUNCIONALIDADE', 6, 8, 1, 'training']
# [869, '/', 'I-FUNCIONALIDADE', 6, 8, 1, 'training']
# [870, 'and', 'I-FUNCIONALIDADE', 6, 8, 1, 'training']
# [871, 'caregiver', 'I-FUNCIONALIDADE', 6, 8, 1, 'training']
# [872, 'live', 'I-FUNCIONALIDADE', 6, 8, 1, 'training']
# [873, 'feedback', 'I-FUNCIONALIDADE', 6, 8, 1, 'training']
# [874, 'about', 'O', 6, 8, 1, 'training']
# [875, 'user', 'O', 6, 8, 1, 'training']
# [876, 'health', 'O', 6, 8, 1, 'training']
# [877, 'metrics', 'O', 6, 8, 1, 'training']
# [878, 'and', 'O', 6, 8, 1, 'training']
# [879, 'status', 'O', 6, 8, 1, 'training']
# [880, 'using', 'O', 6, 8, 1, 'training']
# [881, 'a', 'O', 6, 8, 1, 'training']
# [882, 'data', 'O', 6, 8, 1, 'training']
# [883, 'representation', 'O', 6, 8, 1, 'training']
# [884, 'method', 'O', 6, 8, 1, 'training']
# [885, '.', 'O', 6, 8, 1, 'training']
# [886, 'A', 'O', 1, 9, 1, 'training']
# [887, 'millimeter', 'B-COMUNICAÇÃO', 1, 9, 1, 'training']
# [888, 'wave', 'I-COMUNICAÇÃO', 1, 9, 1, 'training']
# [889, 'communication', 'I-COMUNICAÇÃO', 1, 9, 1, 'training']
# [890, 'system', 'I-COMUNICAÇÃO', 1, 9, 1, 'training']
# [891, 'for', 'O', 1, 9, 1, 'training']
# [892, 'enhanced', 'O', 1, 9, 1, 'training']
# [893, 'downlink', 'O', 1, 9, 1, 'training']
# [894, 'beamforming', 'O', 1, 9, 1, 'training']
# [895, 'and', 'O', 1, 9, 1, 'training']
# [896, 'pairing', 'O', 1, 9, 1, 'training']
# [897, 'is', 'O', 1, 9, 1, 'training']
# [898, 'described', 'O', 1, 9, 1, 'training']
# [899, '.', 'O', 1, 9, 1, 'training']
# [900, 'This', 'O', 2, 9, 1, 'training']
# [901, 'includes', 'O', 2, 9, 1, 'training']
# [902, 'a', 'O', 2, 9, 1, 'training']
# [903, 'beamforming', 'O', 2, 9, 1, 'training']
# [904, 'system', 'O', 2, 9, 1, 'training']
# [905, 'for', 'O', 2, 9, 1, 'training']
# [906, 'pairing', 'O', 2, 9, 1, 'training']
# [907, 'with', 'O', 2, 9, 1, 'training']
# [908, 'a', 'O', 2, 9, 1, 'training']
# [909, 'mobile', 'O', 2, 9, 1, 'training']
# [910, 'UE', 'O', 2, 9, 1, 'training']
# [911, ',', 'O', 2, 9, 1, 'training']
# [912, 'using', 'O', 2, 9, 1, 'training']
# [913, 'a', 'O', 2, 9, 1, 'training']
# [914, 'base', 'O', 2, 9, 1, 'training']
# [915, 'station', 'O', 2, 9, 1, 'training']
# [916, 'with', 'O', 2, 9, 1, 'training']
# [917, 'a', 'O', 2, 9, 1, 'training']
# [918, 'MIMO', 'B-HARDWARE', 2, 9, 1, 'training']
# [919, 'antenna', 'I-HARDWARE', 2, 9, 1, 'training']
# [920, 'and', 'O', 2, 9, 1, 'training']
# [921, 'a', 'O', 2, 9, 1, 'training']
# [922, 'controller', 'B-HARDWARE', 2, 9, 1, 'training']
# [923, '.', 'O', 2, 9, 1, 'training']
# [924, 'The', 'O', 3, 9, 1, 'training']
# [925, 'controller', 'B-HARDWARE', 3, 9, 1, 'training']
# [926, 'transmits', 'B-FUNCIONALIDADE', 3, 9, 1, 'training']
# [927, 'first', 'I-FUNCIONALIDADE', 3, 9, 1, 'training']
# [928, 'downlink', 'I-FUNCIONALIDADE', 3, 9, 1, 'training']
# [929, 'beams', 'I-FUNCIONALIDADE', 3, 9, 1, 'training']
# [930, 'from', 'O', 3, 9, 1, 'training']
# [931, 'the', 'O', 3, 9, 1, 'training']
# [932, 'MIMO', 'B-HARDWARE', 3, 9, 1, 'training']
# [933, 'antenna', 'I-HARDWARE', 3, 9, 1, 'training']
# [934, ',', 'O', 3, 9, 1, 'training']
# [935, 'including', 'O', 3, 9, 1, 'training']
# [936, 'channel', 'O', 3, 9, 1, 'training']
# [937, 'state', 'O', 3, 9, 1, 'training']
# [938, 'information', 'O', 3, 9, 1, 'training']
# [939, '(', 'O', 3, 9, 1, 'training']
# [940, 'CSI', 'O', 3, 9, 1, 'training']
# [941, ')', 'O', 3, 9, 1, 'training']
# [942, 'reference', 'O', 3, 9, 1, 'training']
# [943, 'signals', 'O', 3, 9, 1, 'training']
# [944, '.', 'O', 3, 9, 1, 'training']
# [945, 'The', 'O', 4, 9, 1, 'training']
# [946, 'mobile', 'O', 4, 9, 1, 'training']
# [947, 'UE', 'O', 4, 9, 1, 'training']
# [948, 'identifies', 'B-FUNCIONALIDADE', 4, 9, 1, 'training']
# [949, 'a', 'I-FUNCIONALIDADE', 4, 9, 1, 'training']
# [950, 'provisional', 'I-FUNCIONALIDADE', 4, 9, 1, 'training']
# [951, 'downlink', 'I-FUNCIONALIDADE', 4, 9, 1, 'training']
# [952, 'beam', 'I-FUNCIONALIDADE', 4, 9, 1, 'training']
# [953, 'having', 'O', 4, 9, 1, 'training']
# [954, 'a', 'O', 4, 9, 1, 'training']
# [955, 'highest', 'O', 4, 9, 1, 'training']
# [956, 'intensity', 'O', 4, 9, 1, 'training']
# [957, 'CSI', 'O', 4, 9, 1, 'training']
# [958, 'reference', 'O', 4, 9, 1, 'training']
# [959, 'signal', 'O', 4, 9, 1, 'training']
# [960, 'at', 'O', 4, 9, 1, 'training']
# [961, 'the', 'O', 4, 9, 1, 'training']
# [962, 'mobile', 'O', 4, 9, 1, 'training']
# [963, 'UE', 'O', 4, 9, 1, 'training']
# [964, '.', 'O', 4, 9, 1, 'training']
# [965, 'The', 'O', 5, 9, 1, 'training']
# [966, 'controller', 'B-HARDWARE', 5, 9, 1, 'training']
# [967, 'receives', 'B-FUNCIONALIDADE', 5, 9, 1, 'training']
# [968, 'a', 'I-FUNCIONALIDADE', 5, 9, 1, 'training']
# [969, 'CSI', 'I-FUNCIONALIDADE', 5, 9, 1, 'training']
# [970, 'reference', 'I-FUNCIONALIDADE', 5, 9, 1, 'training']
# [971, 'signal', 'I-FUNCIONALIDADE', 5, 9, 1, 'training']
# [972, 'resource', 'I-FUNCIONALIDADE', 5, 9, 1, 'training']
# [973, 'indicator', 'I-FUNCIONALIDADE', 5, 9, 1, 'training']
# [974, '(', 'I-FUNCIONALIDADE', 5, 9, 1, 'training']
# [975, 'CRI', 'I-FUNCIONALIDADE', 5, 9, 1, 'training']
# [976, ')', 'I-FUNCIONALIDADE', 5, 9, 1, 'training']
# [977, 'feedback', 'I-FUNCIONALIDADE', 5, 9, 1, 'training']
# [978, 'from', 'O', 5, 9, 1, 'training']
# [979, 'the', 'O', 5, 9, 1, 'training']
# [980, 'mobile', 'O', 5, 9, 1, 'training']
# [981, 'UE', 'O', 5, 9, 1, 'training']
# [982, 'that', 'O', 5, 9, 1, 'training']
# [983, 'is', 'O', 5, 9, 1, 'training']
# [984, 'responsive', 'O', 5, 9, 1, 'training']
# [985, 'to', 'O', 5, 9, 1, 'training']
# [986, 'the', 'O', 5, 9, 1, 'training']
# [987, 'downlink', 'O', 5, 9, 1, 'training']
# [988, 'beams', 'O', 5, 9, 1, 'training']
# [989, 'and', 'O', 5, 9, 1, 'training']
# [990, 'includes', 'O', 5, 9, 1, 'training']
# [991, 'the', 'O', 5, 9, 1, 'training']
# [992, 'provisional', 'O', 5, 9, 1, 'training']
# [993, 'downlink', 'O', 5, 9, 1, 'training']
# [994, 'beam', 'O', 5, 9, 1, 'training']
# [995, ',', 'O', 5, 9, 1, 'training']
# [996, 'a', 'O', 5, 9, 1, 'training']
# [997, 'present', 'O', 5, 9, 1, 'training']
# [998, 'geographic', 'O', 5, 9, 1, 'training']
# [999, 'position', 'O', 5, 9, 1, 'training']
# [1000, 'and', 'O', 5, 9, 1, 'training']
# [1001, 'trajectory', 'O', 5, 9, 1, 'training']
# [1002, 'of', 'O', 5, 9, 1, 'training']
# [1003, 'the', 'O', 5, 9, 1, 'training']
# [1004, 'mobile', 'O', 5, 9, 1, 'training']
# [1005, 'UE', 'O', 5, 9, 1, 'training']
# [1006, '.', 'O', 5, 9, 1, 'training']
# [1007, 'A', 'O', 6, 9, 1, 'training']
# [1008, 'refined', 'O', 6, 9, 1, 'training']
# [1009, 'downlink', 'O', 6, 9, 1, 'training']
# [1010, 'beam', 'O', 6, 9, 1, 'training']
# [1011, 'is', 'O', 6, 9, 1, 'training']
# [1012, 'determined', 'O', 6, 9, 1, 'training']
# [1013, 'based', 'O', 6, 9, 1, 'training']
# [1014, 'upon', 'O', 6, 9, 1, 'training']
# [1015, 'the', 'O', 6, 9, 1, 'training']
# [1016, 'provisional', 'O', 6, 9, 1, 'training']
# [1017, 'downlink', 'O', 6, 9, 1, 'training']
# [1018, 'beam', 'O', 6, 9, 1, 'training']
# [1019, ',', 'O', 6, 9, 1, 'training']
# [1020, 'the', 'O', 6, 9, 1, 'training']
# [1021, 'present', 'O', 6, 9, 1, 'training']
# [1022, 'geographic', 'O', 6, 9, 1, 'training']
# [1023, 'position', 'O', 6, 9, 1, 'training']
# [1024, ',', 'O', 6, 9, 1, 'training']
# [1025, 'and', 'O', 6, 9, 1, 'training']
# [1026, 'trajectory', 'O', 6, 9, 1, 'training']
# [1027, 'of', 'O', 6, 9, 1, 'training']
# [1028, 'the', 'O', 6, 9, 1, 'training']
# [1029, 'mobile', 'O', 6, 9, 1, 'training']
# [1030, 'UE', 'O', 6, 9, 1, 'training']
# [1031, '.', 'O', 6, 9, 1, 'training']
# [1032, 'The', 'O', 7, 9, 1, 'training']
# [1033, 'MIMO', 'B-HARDWARE', 7, 9, 1, 'training']
# [1034, 'antenna', 'I-HARDWARE', 7, 9, 1, 'training']
# [1035, 'transmits', 'B-FUNCIONALIDADE', 7, 9, 1, 'training']
# [1036, 'the', 'I-FUNCIONALIDADE', 7, 9, 1, 'training']
# [1037, 'refined', 'I-FUNCIONALIDADE', 7, 9, 1, 'training']
# [1038, 'downlink', 'I-FUNCIONALIDADE', 7, 9, 1, 'training']
# [1039, 'beam', 'I-FUNCIONALIDADE', 7, 9, 1, 'training']
# [1040, 'to', 'O', 7, 9, 1, 'training']
# [1041, 'execute', 'B-FUNCIONALIDADE', 7, 9, 1, 'training']
# [1042, 'a', 'I-FUNCIONALIDADE', 7, 9, 1, 'training']
# [1043, 'pairing', 'I-FUNCIONALIDADE', 7, 9, 1, 'training']
# [1044, 'with', 'O', 7, 9, 1, 'training']
# [1045, 'the', 'O', 7, 9, 1, 'training']
# [1046, 'mobile', 'O', 7, 9, 1, 'training']
# [1047, 'UE', 'O', 7, 9, 1, 'training']
# [1048, '.', 'O', 7, 9, 1, 'training']
# [1049, 'There', 'O', 1, 10, 1, 'training']
# [1050, 'is', 'O', 1, 10, 1, 'training']
# [1051, 'provided', 'O', 1, 10, 1, 'training']
# [1052, 'a', 'O', 1, 10, 1, 'training']
# [1053, 'decentralized', 'O', 1, 10, 1, 'training']
# [1054, 'system', 'O', 1, 10, 1, 'training']
# [1055, 'and', 'O', 1, 10, 1, 'training']
# [1056, 'method', 'O', 1, 10, 1, 'training']
# [1057, 'for', 'O', 1, 10, 1, 'training']
# [1058, 'distributed', 'O', 1, 10, 1, 'training']
# [1059, 'traffic', 'O', 1, 10, 1, 'training']
# [1060, 'management', 'O', 1, 10, 1, 'training']
# [1061, 'comprising', 'O', 1, 10, 1, 'training']
# [1062, ':', 'O', 1, 10, 1, 'training']
# [1063, 'a', 'O', 1, 10, 1, 'training']
# [1064, 'plurality', 'O', 1, 10, 1, 'training']
# [1065, 'of', 'O', 1, 10, 1, 'training']
# [1066, 'intersection', 'O', 1, 10, 1, 'training']
# [1067, 'computing', 'O', 1, 10, 1, 'training']
# [1068, 'agents', 'O', 1, 10, 1, 'training']
# [1069, 'connected', 'O', 1, 10, 1, 'training']
# [1070, 'across', 'O', 1, 10, 1, 'training']
# [1071, 'a', 'O', 1, 10, 1, 'training']
# [1072, 'communication', 'B-COMUNICAÇÃO', 1, 10, 1, 'training']
# [1073, 'network', 'I-COMUNICAÇÃO', 1, 10, 1, 'training']
# [1074, ',', 'O', 1, 10, 1, 'training']
# [1075, 'each', 'O', 1, 10, 1, 'training']
# [1076, 'intersection', 'O', 1, 10, 1, 'training']
# [1077, 'computing', 'O', 1, 10, 1, 'training']
# [1078, 'agent', 'O', 1, 10, 1, 'training']
# [1079, 'located', 'O', 1, 10, 1, 'training']
# [1080, 'at', 'O', 1, 10, 1, 'training']
# [1081, 'a', 'O', 1, 10, 1, 'training']
# [1082, 'particular', 'O', 1, 10, 1, 'training']
# [1083, 'intersection', 'O', 1, 10, 1, 'training']
# [1084, 'communicating', 'O', 1, 10, 1, 'training']
# [1085, 'with', 'O', 1, 10, 1, 'training']
# [1086, 'a', 'O', 1, 10, 1, 'training']
# [1087, 'plurality', 'O', 1, 10, 1, 'training']
# [1088, 'of', 'O', 1, 10, 1, 'training']
# [1089, 'corresponding', 'O', 1, 10, 1, 'training']
# [1090, 'local', 'O', 1, 10, 1, 'training']
# [1091, 'link', 'O', 1, 10, 1, 'training']
# [1092, 'computing', 'O', 1, 10, 1, 'training']
# [1093, 'agents', 'O', 1, 10, 1, 'training']
# [1094, 'comprising', 'O', 1, 10, 1, 'training']
# [1095, 'sensors', 'B-HARDWARE', 1, 10, 1, 'training']
# [1096, 'located', 'O', 1, 10, 1, 'training']
# [1097, 'on', 'O', 1, 10, 1, 'training']
# [1098, 'each', 'O', 1, 10, 1, 'training']
# [1099, 'respective', 'O', 1, 10, 1, 'training']
# [1100, 'road', 'O', 1, 10, 1, 'training']
# [1101, 'link', 'O', 1, 10, 1, 'training']
# [1102, 'directly', 'O', 1, 10, 1, 'training']
# [1103, 'connected', 'O', 1, 10, 1, 'training']
# [1104, 'to', 'O', 1, 10, 1, 'training']
# [1105, 'the', 'O', 1, 10, 1, 'training']
# [1106, 'particular', 'O', 1, 10, 1, 'training']
# [1107, 'intersection', 'O', 1, 10, 1, 'training']
# [1108, ',', 'O', 1, 10, 1, 'training']
# [1109, 'to', 'O', 1, 10, 1, 'training']
# [1110, 'receive', 'B-FUNCIONALIDADE', 1, 10, 1, 'training']
# [1111, 'a', 'I-FUNCIONALIDADE', 1, 10, 1, 'training']
# ...
# [13087, 'a', 'I-FUNCIONALIDADE', 2, 116, 10, 'test']
# [13088, 'labeling', 'I-FUNCIONALIDADE', 2, 116, 10, 'test']
# [13089, 'matrix', 'I-FUNCIONALIDADE', 2, 116, 10, 'test']
# [13090, ',', 'O', 2, 116, 10, 'test']
# [13091, 'computing', 'B-FUNCIONALIDADE', 2, 116, 10, 'test']
# [13092, 'pairwise', 'I-FUNCIONALIDADE', 2, 116, 10, 'test']
# [13093, 'similarity', 'I-FUNCIONALIDADE', 2, 116, 10, 'test']
# [13094, 'scores', 'I-FUNCIONALIDADE', 2, 116, 10, 'test']
# [13095, 'using', 'O', 2, 116, 10, 'test']
# [13096, 'similarity', 'O', 2, 116, 10, 'test']
# [13097, 'metrics', 'O', 2, 116, 10, 'test']
# [13098, 'for', 'O', 2, 116, 10, 'test']
# [13099, 'each', 'O', 2, 116, 10, 'test']
# [13100, 'of', 'O', 2, 116, 10, 'test']
# [13101, 'the', 'O', 2, 116, 10, 'test']
# [13102, 'pairs', 'O', 2, 116, 10, 'test']
# [13103, 'of', 'O', 2, 116, 10, 'test']
# [13104, 'semantic', 'O', 2, 116, 10, 'test']
# [13105, 'concepts', 'O', 2, 116, 10, 'test']
# [13106, ',', 'O', 2, 116, 10, 'test']
# [13107, 'augmenting', 'B-FUNCIONALIDADE', 2, 116, 10, 'test']
# [13108, 'the', 'I-FUNCIONALIDADE', 2, 116, 10, 'test']
# [13109, 'labeling', 'I-FUNCIONALIDADE', 2, 116, 10, 'test']
# [13110, 'matrix', 'I-FUNCIONALIDADE', 2, 116, 10, 'test']
# [13111, 'using', 'O', 2, 116, 10, 'test']
# [13112, 'the', 'O', 2, 116, 10, 'test']
# [13113, 'pairwise', 'O', 2, 116, 10, 'test']
# [13114, 'similarity', 'O', 2, 116, 10, 'test']
# [13115, 'scores', 'O', 2, 116, 10, 'test']
# [13116, 'to', 'O', 2, 116, 10, 'test']
# [13117, 'increase', 'O', 2, 116, 10, 'test']
# [13118, 'a', 'O', 2, 116, 10, 'test']
# [13119, 'density', 'O', 2, 116, 10, 'test']
# [13120, 'of', 'O', 2, 116, 10, 'test']
# [13121, 'the', 'O', 2, 116, 10, 'test']
# [13122, 'labeling', 'O', 2, 116, 10, 'test']
# [13123, 'matrix', 'O', 2, 116, 10, 'test']
# [13124, ',', 'O', 2, 116, 10, 'test']
# [13125, 'and', 'O', 2, 116, 10, 'test']
# [13126, 'inputting', 'O', 2, 116, 10, 'test']
# [13127, 'the', 'O', 2, 116, 10, 'test']
# [13128, 'labeling', 'O', 2, 116, 10, 'test']
# [13129, 'matrix', 'O', 2, 116, 10, 'test']
# [13130, 'to', 'O', 2, 116, 10, 'test']
# [13131, 'a', 'O', 2, 116, 10, 'test']
# [13132, 'label', 'O', 2, 116, 10, 'test']
# [13133, 'aggregator', 'O', 2, 116, 10, 'test']
# [13134, 'to', 'O', 2, 116, 10, 'test']
# [13135, 'apply', 'O', 2, 116, 10, 'test']
# [13136, 'a', 'O', 2, 116, 10, 'test']
# [13137, 'single', 'O', 2, 116, 10, 'test']
# [13138, 'label', 'O', 2, 116, 10, 'test']
# [13139, 'for', 'O', 2, 116, 10, 'test']
# [13140, 'each', 'O', 2, 116, 10, 'test']
# [13141, 'of', 'O', 2, 116, 10, 'test']
# [13142, 'the', 'O', 2, 116, 10, 'test']
# [13143, 'pairs', 'O', 2, 116, 10, 'test']
# [13144, 'of', 'O', 2, 116, 10, 'test']
# [13145, 'semantic', 'O', 2, 116, 10, 'test']
# [13146, 'concepts', 'O', 2, 116, 10, 'test']
# [13147, 'labeled', 'O', 2, 116, 10, 'test']
# [13148, 'by', 'O', 2, 116, 10, 'test']
# [13149, 'the', 'O', 2, 116, 10, 'test']
# [13150, 'at', 'O', 2, 116, 10, 'test']
# [13151, 'least', 'O', 2, 116, 10, 'test']
# [13152, 'one', 'O', 2, 116, 10, 'test']
# [13153, 'labeling', 'O', 2, 116, 10, 'test']
# [13154, 'function', 'O', 2, 116, 10, 'test']
# [13155, '.', 'O', 2, 116, 10, 'test']
# [13156, 'A', 'O', 1, 117, 10, 'test']
# [13157, 'method', 'O', 1, 117, 10, 'test']
# [13158, 'of', 'O', 1, 117, 10, 'test']
# [13159, 'controlling', 'B-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13160, 'an', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13161, 'artificial', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13162, 'intelligence', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13163, '(', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13164, 'AI', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13165, ')', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13166, 'mobility', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13167, 'device', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13168, 'can', 'O', 1, 117, 10, 'test']
# [13169, 'include', 'O', 1, 117, 10, 'test']
# [13170, 'acquiring', 'B-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13171, 'personal', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13172, 'information', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13173, 'of', 'O', 1, 117, 10, 'test']
# [13174, 'a', 'O', 1, 117, 10, 'test']
# [13175, 'driver', 'B-PESSOA', 1, 117, 10, 'test']
# [13176, 'and', 'O', 1, 117, 10, 'test']
# [13177, 'setting', 'B-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13178, 'a', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13179, 'driving', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13180, 'level', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13181, 'based', 'O', 1, 117, 10, 'test']
# [13182, 'on', 'O', 1, 117, 10, 'test']
# [13183, 'the', 'O', 1, 117, 10, 'test']
# [13184, 'personal', 'O', 1, 117, 10, 'test']
# [13185, 'information', 'O', 1, 117, 10, 'test']
# [13186, 'of', 'O', 1, 117, 10, 'test']
# [13187, 'the', 'O', 1, 117, 10, 'test']
# [13188, 'driver', 'B-PESSOA', 1, 117, 10, 'test']
# [13189, ';', 'O', 1, 117, 10, 'test']
# [13190, 'acquiring', 'B-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13191, 'driving', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13192, 'information', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13193, 'of', 'O', 1, 117, 10, 'test']
# [13194, 'the', 'O', 1, 117, 10, 'test']
# [13195, 'driver', 'B-PESSOA', 1, 117, 10, 'test']
# [13196, 'based', 'O', 1, 117, 10, 'test']
# [13197, 'on', 'O', 1, 117, 10, 'test']
# [13198, 'the', 'O', 1, 117, 10, 'test']
# [13199, 'driving', 'O', 1, 117, 10, 'test']
# [13200, 'level', 'O', 1, 117, 10, 'test']
# [13201, 'while', 'O', 1, 117, 10, 'test']
# [13202, 'the', 'O', 1, 117, 10, 'test']
# [13203, 'driver', 'B-PESSOA', 1, 117, 10, 'test']
# [13204, 'is', 'O', 1, 117, 10, 'test']
# [13205, 'driving', 'O', 1, 117, 10, 'test']
# [13206, ';', 'O', 1, 117, 10, 'test']
# [13207, 'determining', 'B-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13208, 'a', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13209, 'skill', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13210, 'status', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13211, 'of', 'O', 1, 117, 10, 'test']
# [13212, 'the', 'O', 1, 117, 10, 'test']
# [13213, 'driver', 'B-PESSOA', 1, 117, 10, 'test']
# [13214, 'based', 'O', 1, 117, 10, 'test']
# [13215, 'on', 'O', 1, 117, 10, 'test']
# [13216, 'the', 'O', 1, 117, 10, 'test']
# [13217, 'driving', 'O', 1, 117, 10, 'test']
# [13218, 'information', 'O', 1, 117, 10, 'test']
# [13219, 'of', 'O', 1, 117, 10, 'test']
# [13220, 'the', 'O', 1, 117, 10, 'test']
# [13221, 'driver', 'O', 1, 117, 10, 'test']
# [13222, ';', 'O', 1, 117, 10, 'test']
# [13223, 'applying', 'B-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13224, 'road', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13225, 'information', 'I-FUNCIONALIDADE', 1, 117, 10, 'test']
# [13226, 'corresponding', 'O', 1, 117, 10, 'test']
# [13227, 'to', 'O', 1, 117, 10, 'test']
# [13228, 'the', 'O', 1, 117, 10, 'test']
# [13229, 'skill', 'O', 1, 117, 10, 'test']
# [13230, 'status', 'O', 1, 117, 10, 'test']
# [13231, 'of', 'O', 1, 117, 10, 'test']
# [13232, 'the', 'O', 1, 117, 10, 'test']
# [13233, 'driver', 'B-PESSOA', 1, 117, 10, 'test']
# [13234, ';', 'O', 1, 117, 10, 'test']
# [13235, 'and', 'O', 1, 117, 10, 'test']
# [13236, 'in', 'O', 1, 117, 10, 'test']
# [13237, 'response', 'O', 1, 117, 10, 'test']
# [13238, 'to', 'O', 1, 117, 10, 'test']
# [13239, 'determining', 'O', 1, 117, 10, 'test']
# [13240, 'that', 'O', 1, 117, 10, 'test']
# [13241, 'the', 'O', 1, 117, 10, 'test']
# [13242, 'skill', 'O', 1, 117, 10, 'test']
# [13243, 'status', 'O', 1, 117, 10, 'test']
# [13244, 'of', 'O', 1, 117, 10, 'test']
# [13245, 'the', 'O', 1, 117, 10, 'test']
# [13246, 'driver', 'B-PESSOA', 1, 117, 10, 'test']
# [13247, 'is', 'O', 1, 117, 10, 'test']
# [13248, 'lower', 'O', 1, 117, 10, 'test']
# [13249, 'than', 'O', 1, 117, 10, 'test']
# [13250, 'a', 'O', 1, 117, 10, 'test']
# [13251, 'predetermined', 'O', 1, 117, 10, 'test']
# [13252, 'reference', 'O', 1, 117, 10, 'test']
# [13253, 'based', 'O', 1, 117, 10, 'test']
# [13254, 'on', 'O', 1, 117, 10, 'test']
# [13255, 'the', 'O', 1, 117, 10, 'test']
# [13256, 'road', 'O', 1, 117, 10, 'test']
# [13257, 'information', 'O', 1, 117, 10, 'test']
# [13258, ',', 'O', 1, 117, 10, 'test']
# [13259, 'outputting', 'O', 1, 117, 10, 'test']
# [13260, 'a', 'O', 1, 117, 10, 'test']
# [13261, 'warning', 'O', 1, 117, 10, 'test']
# [13262, 'and', 'O', 1, 117, 10, 'test']
# [13263, 'executing', 'O', 1, 117, 10, 'test']
# [13264, 'a', 'O', 1, 117, 10, 'test']
# [13265, 'function', 'O', 1, 117, 10, 'test']
# [13266, 'of', 'O', 1, 117, 10, 'test']
# [13267, 'the', 'O', 1, 117, 10, 'test']
# [13268, 'AI', 'B-HARDWARE', 1, 117, 10, 'test']
# [13269, 'mobility', 'I-HARDWARE', 1, 117, 10, 'test']
# [13270, 'device', 'I-HARDWARE', 1, 117, 10, 'test']
# [13271, 'based', 'O', 1, 117, 10, 'test']
# [13272, 'on', 'O', 1, 117, 10, 'test']
# [13273, 'the', 'O', 1, 117, 10, 'test']
# [13274, 'warning', 'O', 1, 117, 10, 'test']
# [13275, '.', 'O', 1, 117, 10, 'test']
# [13276, 'The', 'O', 1, 118, 10, 'test']
# [13277, 'present', 'O', 1, 118, 10, 'test']
# [13278, 'disclosure', 'O', 1, 118, 10, 'test']
# [13279, 'relates', 'O', 1, 118, 10, 'test']
# [13280, 'to', 'O', 1, 118, 10, 'test']
# [13281, 'a', 'O', 1, 118, 10, 'test']
# [13282, 'sensor', 'B-HARDWARE', 1, 118, 10, 'test']
# [13283, 'network', 'I-HARDWARE', 1, 118, 10, 'test']
# [13284, ',', 'O', 1, 118, 10, 'test']
# [13285, 'machine', 'B-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13286, 'type', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13287, 'communication', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13288, '(', 'O', 1, 118, 10, 'test']
# [13289, 'MTC', 'B-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13290, ')', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13291, ',', 'O', 1, 118, 10, 'test']
# [13292, 'machine', 'B-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13293, '-', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13294, 'to', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13295, '-', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13296, 'machine', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13297, '(', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13298, 'M2M', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13299, ')', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13300, 'communication', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13301, ',', 'O', 1, 118, 10, 'test']
# [13302, 'and', 'O', 1, 118, 10, 'test']
# [13303, 'technology', 'B-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13304, 'for', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13305, 'internet', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13306, 'of', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13307, 'things', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13308, '(', 'O', 1, 118, 10, 'test']
# [13309, 'IoT', 'B-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13310, ')', 'I-COMUNICAÇÃO', 1, 118, 10, 'test']
# [13311, '.', 'O', 1, 118, 10, 'test']
# [13312, 'The', 'O', 2, 118, 10, 'test']
# [13313, 'present', 'O', 2, 118, 10, 'test']
# [13314, 'disclosure', 'O', 2, 118, 10, 'test']
# [13315, 'may', 'O', 2, 118, 10, 'test']
# [13316, 'be', 'O', 2, 118, 10, 'test']
# [13317, 'applied', 'O', 2, 118, 10, 'test']
# [13318, 'to', 'O', 2, 118, 10, 'test']
# [13319, 'intelligent', 'O', 2, 118, 10, 'test']
# [13320, 'services', 'O', 2, 118, 10, 'test']
# [13321, 'based', 'O', 2, 118, 10, 'test']
# [13322, 'on', 'O', 2, 118, 10, 'test']
# [13323, 'the', 'O', 2, 118, 10, 'test']
# [13324, 'above', 'O', 2, 118, 10, 'test']
# [13325, 'technologies', 'O', 2, 118, 10, 'test']
# [13326, ',', 'O', 2, 118, 10, 'test']
# [13327, 'such', 'O', 2, 118, 10, 'test']
# [13328, 'as', 'O', 2, 118, 10, 'test']
# [13329, 'smart', 'O', 2, 118, 10, 'test']
# [13330, 'home', 'O', 2, 118, 10, 'test']
# [13331, ',', 'O', 2, 118, 10, 'test']
# [13332, 'smart', 'O', 2, 118, 10, 'test']
# [13333, 'building', 'O', 2, 118, 10, 'test']
# [13334, ',', 'O', 2, 118, 10, 'test']
# [13335, 'smart', 'O', 2, 118, 10, 'test']
# [13336, 'city', 'O', 2, 118, 10, 'test']
# [13337, ',', 'O', 2, 118, 10, 'test']
# [13338, 'smart', 'O', 2, 118, 10, 'test']
# [13339, 'car', 'O', 2, 118, 10, 'test']
# [13340, ',', 'O', 2, 118, 10, 'test']
# [13341, 'connected', 'O', 2, 118, 10, 'test']
# [13342, 'car', 'O', 2, 118, 10, 'test']
# [13343, ',', 'O', 2, 118, 10, 'test']
# [13344, 'health', 'O', 2, 118, 10, 'test']
# [13345, 'care', 'O', 2, 118, 10, 'test']
# [13346, ',', 'O', 2, 118, 10, 'test']
# [13347, 'digital', 'O', 2, 118, 10, 'test']
# [13348, 'education', 'O', 2, 118, 10, 'test']
# [13349, ',', 'O', 2, 118, 10, 'test']
# [13350, 'smart', 'O', 2, 118, 10, 'test']
# [13351, 'retail', 'O', 2, 118, 10, 'test']
# [13352, ',', 'O', 2, 118, 10, 'test']
# [13353, 'security', 'O', 2, 118, 10, 'test']
# [13354, 'and', 'O', 2, 118, 10, 'test']
# [13355, 'safety', 'O', 2, 118, 10, 'test']
# [13356, 'services', 'O', 2, 118, 10, 'test']
# [13357, '.', 'O', 2, 118, 10, 'test']
# [13358, 'A', 'O', 3, 118, 10, 'test']
# [13359, 'transmitting', 'B-HARDWARE', 3, 118, 10, 'test']
# [13360, 'apparatus', 'I-HARDWARE', 3, 118, 10, 'test']
# [13361, 'according', 'O', 3, 118, 10, 'test']
# [13362, 'to', 'O', 3, 118, 10, 'test']
# [13363, 'an', 'O', 3, 118, 10, 'test']
# [13364, 'embodiment', 'O', 3, 118, 10, 'test']
# [13365, 'of', 'O', 3, 118, 10, 'test']
# [13366, 'the', 'O', 3, 118, 10, 'test']
# [13367, 'present', 'O', 3, 118, 10, 'test']
# [13368, 'disclosure', 'O', 3, 118, 10, 'test']
# [13369, 'is', 'O', 3, 118, 10, 'test']
# [13370, 'provided', 'O', 3, 118, 10, 'test']
# [13371, '.', 'O', 3, 118, 10, 'test']
# [13372, 'The', 'O', 4, 118, 10, 'test']
# [13373, 'transmitting', 'B-HARDWARE', 4, 118, 10, 'test']
# [13374, 'apparatus', 'I-HARDWARE', 4, 118, 10, 'test']
# [13375, 'includes', 'O', 4, 118, 10, 'test']
# [13376, 'a', 'O', 4, 118, 10, 'test']
# [13377, 'transmitter', 'B-HARDWARE', 4, 118, 10, 'test']
# [13378, ',', 'O', 4, 118, 10, 'test']
# [13379, 'and', 'O', 4, 118, 10, 'test']
# [13380, 'a', 'O', 4, 118, 10, 'test']
# [13381, 'processor', 'B-HARDWARE', 4, 118, 10, 'test']
# [13382, 'configured', 'O', 4, 118, 10, 'test']
# [13383, 'to', 'O', 4, 118, 10, 'test']
# [13384, 'acquire', 'B-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13385, 'at', 'I-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13386, 'least', 'I-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13387, 'one', 'I-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13388, 'of', 'I-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13389, 'information', 'I-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13390, 'related', 'I-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13391, 'to', 'I-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13392, 'air', 'I-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13393, 'pollution', 'I-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13394, 'and', 'O', 4, 118, 10, 'test']
# [13395, 'information', 'O', 4, 118, 10, 'test']
# [13396, 'related', 'O', 4, 118, 10, 'test']
# [13397, 'to', 'O', 4, 118, 10, 'test']
# [13398, 'a', 'O', 4, 118, 10, 'test']
# [13399, 'noise', 'O', 4, 118, 10, 'test']
# [13400, 'through', 'O', 4, 118, 10, 'test']
# [13401, 'a', 'O', 4, 118, 10, 'test']
# [13402, 'sensor', 'B-HARDWARE', 4, 118, 10, 'test']
# [13403, 'included', 'O', 4, 118, 10, 'test']
# [13404, 'in', 'O', 4, 118, 10, 'test']
# [13405, 'the', 'O', 4, 118, 10, 'test']
# [13406, 'transmitting', 'B-HARDWARE', 4, 118, 10, 'test']
# [13407, 'apparatus', 'I-HARDWARE', 4, 118, 10, 'test']
# [13408, 'or', 'O', 4, 118, 10, 'test']
# [13409, 'an', 'O', 4, 118, 10, 'test']
# [13410, 'external', 'B-HARDWARE', 4, 118, 10, 'test']
# [13411, 'sensor', 'I-HARDWARE', 4, 118, 10, 'test']
# [13412, ',', 'O', 4, 118, 10, 'test']
# [13413, 'and', 'O', 4, 118, 10, 'test']
# [13414, 'to', 'O', 4, 118, 10, 'test']
# [13415, 'control', 'B-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13416, 'the', 'I-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13417, 'transmitter', 'I-FUNCIONALIDADE', 4, 118, 10, 'test']
# [13418, 'to', 'O', 4, 118, 10, 'test']
# [13419, 'transmit', 'O', 4, 118, 10, 'test']
# [13420, 'the', 'O', 4, 118, 10, 'test']
# [13421, 'at', 'O', 4, 118, 10, 'test']
# [13422, 'least', 'O', 4, 118, 10, 'test']
# [13423, 'one', 'O', 4, 118, 10, 'test']
# [13424, 'of', 'O', 4, 118, 10, 'test']
# [13425, 'the', 'O', 4, 118, 10, 'test']
# [13426, 'information', 'O', 4, 118, 10, 'test']
# [13427, 'related', 'O', 4, 118, 10, 'test']
# [13428, 'to', 'O', 4, 118, 10, 'test']
# [13429, 'the', 'O', 4, 118, 10, 'test']
# [13430, 'air', 'O', 4, 118, 10, 'test']
# [13431, 'pollution', 'O', 4, 118, 10, 'test']
# [13432, 'and', 'O', 4, 118, 10, 'test']
# [13433, 'the', 'O', 4, 118, 10, 'test']
# [13434, 'information', 'O', 4, 118, 10, 'test']
# [13435, 'related', 'O', 4, 118, 10, 'test']
# [13436, 'to', 'O', 4, 118, 10, 'test']
# [13437, 'the', 'O', 4, 118, 10, 'test']
# [13438, 'noise', 'O', 4, 118, 10, 'test']
# [13439, '.', 'O', 4, 118, 10, 'test']

# %%
headers = ["item", "token", "tag", "sentence", "patent", "partition", "trainingTest"]

with open('final_dataset.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    
    writer.writerow(headers)
    writer.writerows(dataset)
